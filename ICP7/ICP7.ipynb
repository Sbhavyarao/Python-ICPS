# %%
from bs4 import BeautifulSoup
import requests

url = 'https://en.wikipedia.org/wiki/Google'
response = requests.get(url)

content = BeautifulSoup(response.content, "html.parser")
text = content.get_text()

# %%
file = open("myfile.txt","w")
file.write(text)
file.close()

# %%
import nltk
nltk.download('punkt')

file = open('myfile.txt', 'r', encoding='utf-8')
input = file.read()

stokens = nltk.sent_tokenize(input)
wtokens = nltk.word_tokenize(input)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.download('averaged_perceptron_tagger')

print(nltk.pos_tag(wtokens))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Google', 'NNP'), ('-', ':'), ('Wikipedia', 'NNP'), ('document.documentElement.className=', 'NN'), ("''", "''"), ('client-js', 'NN'), ("''", "''"), (';', ':'), ('RLCONF=', 'NNP'), ('{', '('), ('``', '``'), ('wgBreakFrames', 'NNS'), ("''", "''"), (':', ':'), ('!', '.'), ('1', 'CD'), (',', ','), ("''", "''"), ('wgSeparatorTransformTable', 'JJ'), ("''", "''"), (':', ':'), ('[', 'VB'), ('``', '``'), ("''", "''"), (',', ','), ("''", "''"), ("''", "''"), (']', 'NN'), (',', ','), ("''", "''"), ('wgDigitTransformTable', 'JJ'), ("''", "''"), (':', ':'), ('[', 'VB'), ('``', '``'), ("''", "''"), (',', ','), ("''", "''"), ("''", "''"), (']', 'NN'), (',', ','), ("''", "''"), ('wgDefaultDateFormat', 'NN'), ("''", "''"), (':', ':'), ("''", "''"), ('dmy', 'NN'), ("''", "''"), (',', ','), ("''", "''"), ('wgMonthNames', 'VBZ'), ("''", "''"), (':', ':'), ('[', 'VB'), ('``', '``'), ("''", "''"), (',', ','), ("''", "''"), ('January', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('February', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('March', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('April', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('May', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('June', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('July', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('August', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('September', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('October', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('November', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('December', 'NNP'), ("''", "''"), (']', 'NN'), (',', ','), ("''", "''"), ('wgMonthNamesShort', 'NN'), ("''", "''"), (':', ':'), ('[', 'VB'), ('``', '``'), ("''", "''"), (',', ','), ("''", "''"), ('Jan', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Feb', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Mar', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Apr', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('May', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Jun', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Jul', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Aug', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Sep', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Oct', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Nov', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('Dec', 'NNP'), ("''", "''"), (']', 'NN'), (',', ','), ("''", "''"), ('wgRequestId', 'NN'), ("''", "''"), (':', ':'), ("''", "''"), ('XmGOHApAEKIAAH1ZY5EAAABX', 'NN'), ("''", "''"), (',', ','), ("''", "''"), ('wgCSPNonce', 'NN'), ("''", "''"), (':', ':'), ('!', '.'), ('1', 'CD'), (',', ','), ("''", "''"), ('wgCanonicalNamespace', 'NN'), ("''", "''"), (':', ':'), ("''", "''"), ("''", "''"), (',', ','), ("''", "''"), ('wgCanonicalSpecialPageName', 'NN'), ("''", "''"), (':', ':'), ('!', '.'), ('1', 'CD'), (',', ','), ("''", "''"), ('wgNamespaceNumber', 'NN'), ("''", "''"), (':0', 'NN'), (',', ','), ("''", "''"), ('wgPageName', 'NN'), ("''", "''"), (':', ':'), ("''", "''"), ('Google', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('wgTitle', 'NN'), ("''", "''"), (':', ':'), ("''", "''"), ('Google', 'NNP'), ("''", "''"), (',', ','), ("''", "''"), ('wgCurRevisionId', 'NN'), ("''", "''"), (':942810543', 'NN'), (',', ','), ("''", "''"), ('wgRevisionId', 'NN'), ("''", "''"), (':942810543', 'NN'), (',', ','), ("''", "''"), ('wgArticleId', 'NN'), ("''", "''"), (':1092923', 'NN'), (',', ','), ("''", "''"), ('wgIsArticle', 'NN'), ("''", "''"), (':', ':'), ('!', '.'), ('0', 'CD'), (',', ','), ("''", "''"), ('wgIsRedirect', 'NN'), ("''", "''"), (':', ':'), ('!', '.'), ('1', 'CD'), (',', ','), ("''", "''"), ('wgAction', 'NN'), ("''", "''"), (':', ':'), ("''", "''"), ('view', 'NN'), ("''", "''"), (',', ','), ("''", "''"), ('wgUserName', 'NN'), ("''", "''"), (':', ':'), ('null', 'NN'), (',', ','), ("''", "''"), ('wgUserGroups', 'NN'), ("''", "''"), (':', ':'), ('[', 'VB'), ('``', '``'), ('*', 'JJ'), ("''", "''" ...

# %%
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.stem import LancasterStemmer

ps = PorterStemmer()
sb = SnowballStemmer('english')
lc = LancasterStemmer()
#for x in wtokens:
 #   print(ps.stem(x))

# %%
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

wtokens = nltk.word_tokenize(input)

lemmatizer = WordNetLemmatizer()

#for x in wtokens:
 #   print(lemmatizer.lemmatize(x))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('words')
bigrams = nltk.trigrams(wtokens)

for b in bigrams:
  print(b)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('architecture', "''", '.')
# ("''", '.', 'IEEE')
# ('.', 'IEEE', 'Micro')
# ('IEEE', 'Micro', '.')
# ('Micro', '.', '23')
# ('.', '23', '(')
# ('23', '(', '2')
# ('(', '2', ')')
# ('2', ')', ':')
# (')', ':', '22–28')
# (':', '22–28', '.')
# ('22–28', '.', 'doi:10.1109/mm.2003.1196112')
# ('.', 'doi:10.1109/mm.2003.1196112', '.')
# ('doi:10.1109/mm.2003.1196112', '.', 'ISSN')
# ('.', 'ISSN', '0272-1732')
# ('ISSN', '0272-1732', '.')
# ('0272-1732', '.', 'We')
# ('.', 'We', 'believe')
# ('We', 'believe', 'that')
# ('believe', 'that', 'the')
# ('that', 'the', 'best')
# ('the', 'best', 'price/performance')
# ('best', 'price/performance', 'tradeoff')
# ('price/performance', 'tradeoff', 'for')
# ('tradeoff', 'for', 'our')
# ('for', 'our', 'applications')
# ('our', 'applications', 'comes')
# ('applications', 'comes', 'from')
# ('comes', 'from', 'fashioning')
# ('from', 'fashioning', 'a')
# ('fashioning', 'a', 'reliable')
# ('a', 'reliable', 'computing')
# ('reliable', 'computing', 'infrastructure')
# ('computing', 'infrastructure', 'from')
# ('infrastructure', 'from', 'clusters')
# ('from', 'clusters', 'of')
# ('clusters', 'of', 'unreliable')
# ('of', 'unreliable', 'commodity')
# ('unreliable', 'commodity', 'PCs')
# ('commodity', 'PCs', '.')
# ('PCs', '.', '^')
# ('.', '^', 'a')
# ('^', 'a', 'b')
# ('a', 'b', '``')
# ('b', '``', 'Google')
# ('``', 'Google', 'uncloaks')
# ('Google', 'uncloaks', 'once-secret')
# ('uncloaks', 'once-secret', 'server')
# ('once-secret', 'server', "''")
# ('server', "''", '.')
# ("''", '.', 'CNET')
# ('.', 'CNET', '.')
# ('CNET', '.', 'April')
# ('.', 'April', '1')
# ('April', '1', ',')
# ('1', ',', '2009')
# (',', '2009', '.')
# ('2009', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'June')
# ('on', 'June', '6')
# ('June', '6', ',')
# ('6', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Retrieved')
# ('.', 'Retrieved', 'May')
# ('Retrieved', 'May', '26')
# ('May', '26', ',')
# ('26', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Mainstream')
# ('.', 'Mainstream', 'servers')
# ('Mainstream', 'servers', 'with')
# ('servers', 'with', 'x86')
# ('with', 'x86', 'processors')
# ('x86', 'processors', 'were')
# ('processors', 'were', 'the')
# ('were', 'the', 'only')
# ('the', 'only', 'option')
# ('only', 'option', ',')
# ('option', ',', 'he')
# (',', 'he', 'added')
# ('he', 'added', '.')
# ('added', '.', '``')
# ('.', '``', 'Ten')
# ('``', 'Ten', 'years')
# ('Ten', 'years', 'ago')
# ('years', 'ago', '...')
# ('ago', '...', 'it')
# ('...', 'it', 'was')
# ('it', 'was', 'clear')
# ('was', 'clear', 'the')
# ('clear', 'the', 'only')
# ('the', 'only', 'way')
# ('only', 'way', 'to')
# ('way', 'to', 'make')
# ('to', 'make', '(')
# ('make', '(', 'search')
# ('(', 'search', ')')
# ('search', ')', 'work')
# (')', 'work', 'as')
# ('work', 'as', 'free')
# ('as', 'free', 'product')
# ('free', 'product', 'was')
# ('product', 'was', 'to')
# ('was', 'to', 'run')
# ('to', 'run', 'on')
# ('run', 'on', 'relatively')
# ('on', 'relatively', 'cheap')
# ('relatively', 'cheap', 'hardware')
# ('cheap', 'hardware', '.')
# ('hardware', '.', 'You')
# ('.', 'You', 'ca')
# ('You', 'ca', "n't")
# ('ca', "n't", 'run')
# ("n't", 'run', 'it')
# ('run', 'it', 'on')
# ('it', 'on', 'a')
# ('on', 'a', 'mainframe')
# ('a', 'mainframe', '.')
# ('mainframe', '.', 'The')
# ('.', 'The', 'margins')
# ('The', 'margins', 'just')
# ('margins', 'just', 'do')
# ('just', 'do', "n't")
# ('do', "n't", 'work')
# ("n't", 'work', 'out')
# ('work', 'out', ',')
# ('out', ',', "''")
# (',', "''", 'he')
# ("''", 'he', 'said')
# ('he', 'said', '.')
# ('said', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'and')
# ('Google', 'and', 'other')
# ('and', 'other', 'tech')
# ('other', 'tech', 'giants')
# ('tech', 'giants', 'are')
# ('giants', 'are', 'quietly')
# ('are', 'quietly', 'buying')
# ('quietly', 'buying', 'up')
# ('buying', 'up', 'the')
# ('up', 'the', 'most')
# ('the', 'most', 'important')
# ('most', 'important', 'part')
# ('important', 'part', 'of')
# ('part', 'of', 'the')
# ('of', 'the', 'internet')
# ('the', 'internet', "''")
# ('internet', "''", '.')
# ("''", '.', 'VentureBeat')
# ('.', 'VentureBeat', '.')
# ('VentureBeat', '.', 'April')
# ('.', 'April', '6')
# ('April', '6', ',')
# ('6', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'April')
# ('on', 'April', '25')
# ('April', '25', ',')
# ('25', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Retrieved')
# ('.', 'Retrieved', 'April')
# ('Retrieved', 'April', '25')
# ('April', '25', ',')
# ('25', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'Sawers')
# ('^', 'Sawers', ',')
# ('Sawers', ',', 'Paul')
# (',', 'Paul', '(')
# ('Paul', '(', 'April')
# ('(', 'April', '24')
# ('April', '24', ',')
# ('24', ',', '2019')
# (',', '2019', ')')
# ('2019', ')', '.')
# (')', '.', '``')
# ('.', '``', 'How')
# ('``', 'How', 'Google')
# ('How', 'Google', 'is')
# ('Google', 'is', 'building')
# ('is', 'building', 'its')
# ('building', 'its', 'huge')
# ('its', 'huge', 'subsea')
# ('huge', 'subsea', 'cable')
# ('subsea', 'cable', 'infrastructure')
# ('cable', 'infrastructure', "''")
# ('infrastructure', "''", '.')
# ("''", '.', 'VentureBeat')
# ('.', 'VentureBeat', '.')
# ('VentureBeat', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'April')
# ('on', 'April', '25')
# ('April', '25', ',')
# ('25', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Retrieved')
# ('.', 'Retrieved', 'April')
# ('Retrieved', 'April', '26')
# ('April', '26', ',')
# ('26', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'a')
# ('^', 'a', 'b')
# ('a', 'b', 'Richmond')
# ('b', 'Richmond', ',')
# ('Richmond', ',', 'Riva')
# (',', 'Riva', '(')
# ('Riva', '(', 'October')
# ('(', 'October', '17')
# ('October', '17', ',')
# ('17', ',', '2006')
# (',', '2006', ')')
# ('2006', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'plans')
# ('Google', 'plans', 'to')
# ('plans', 'to', 'build')
# ('to', 'build', 'huge')
# ('build', 'huge', 'solar')
# ('huge', 'solar', 'energy')
# ('solar', 'energy', 'system')
# ('energy', 'system', 'for')
# ('system', 'for', 'headquarters')
# ('for', 'headquarters', "''")
# ('headquarters', "''", '.')
# ("''", '.', 'post1.net')
# ('.', 'post1.net', '.')
# ('post1.net', '.', 'MarketWatch')
# ('.', 'MarketWatch', '.')
# ('MarketWatch', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'May')
# ('on', 'May', '19')
# ('May', '19', ',')
# ('19', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'October')
# ('Retrieved', 'October', '17')
# ('October', '17', ',')
# ('17', ',', '2006')
# (',', '2006', '.')
# ('2006', '.', '^')
# ('.', '^', 'McGrath')
# ('^', 'McGrath', ',')
# ('McGrath', ',', 'Jack')
# (',', 'Jack', '(')
# ('Jack', '(', 'May')
# ('(', 'May', '18')
# ('May', '18', ',')
# ('18', ',', '2011')
# (',', '2011', ')')
# ('2011', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', "'s")
# ('Google', "'s", 'Green')
# ("'s", 'Green', 'Initiative')
# ('Green', 'Initiative', ':')
# ('Initiative', ':', 'Environmentally')
# (':', 'Environmentally', 'Conscious')
# ('Environmentally', 'Conscious', 'Technology')
# ('Conscious', 'Technology', "''")
# ('Technology', "''", '.')
# ("''", '.', 'TechnoBuffalo')
# ('.', 'TechnoBuffalo', '.')
# ('TechnoBuffalo', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'October')
# ('on', 'October', '12')
# ('October', '12', ',')
# ('12', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'January')
# ('Retrieved', 'January', '22')
# ('January', '22', ',')
# ('22', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', 'Glanz')
# ('^', 'Glanz', ',')
# ('Glanz', ',', 'James')
# (',', 'James', '(')
# ('James', '(', 'September')
# ('(', 'September', '8')
# ('September', '8', ',')
# ('8', ',', '2011')
# (',', '2011', ')')
# ('2011', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'Details')
# ('Google', 'Details', ',')
# ('Details', ',', 'and')
# (',', 'and', 'Defends')
# ('and', 'Defends', ',')
# ('Defends', ',', 'Its')
# (',', 'Its', 'Use')
# ('Its', 'Use', 'of')
# ('Use', 'of', 'Electricity')
# ('of', 'Electricity', "''")
# ('Electricity', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'New')
# ('The', 'New', 'York')
# ('New', 'York', 'Times')
# ('York', 'Times', '.')
# ('Times', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'March')
# ('on', 'March', '12')
# ('March', '12', ',')
# ('12', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '9')
# ('March', '9', ',')
# ('9', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', 'Morrison')
# ('^', 'Morrison', ',')
# ('Morrison', ',', 'Scott')
# (',', 'Scott', ';')
# ('Scott', ';', 'Sweet')
# (';', 'Sweet', ',')
# ('Sweet', ',', 'Cassandra')
# (',', 'Cassandra', '(')
# ('Cassandra', '(', 'May')
# ('(', 'May', '4')
# ('May', '4', ',')
# ('4', ',', '2010')
# (',', '2010', ')')
# ('2010', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'Invests')
# ('Google', 'Invests', 'in')
# ('Invests', 'in', 'Two')
# ('in', 'Two', 'Wind')
# ('Two', 'Wind', 'Farms')
# ('Wind', 'Farms', "''")
# ('Farms', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Wall')
# ('The', 'Wall', 'Street')
# ('Wall', 'Street', 'Journal')
# ('Street', 'Journal', '.')
# ('Journal', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'February')
# ('on', 'February', '13')
# ('February', '13', ',')
# ('13', ',', '2015')
# (',', '2015', '.')
# ('2015', '.', 'Retrieved')
# ('.', 'Retrieved', 'November')
# ('Retrieved', 'November', '27')
# ('November', '27', ',')
# ('27', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'Energy')
# ('Google', 'Energy', 'can')
# ('Energy', 'can', 'now')
# ('can', 'now', 'buy')
# ('now', 'buy', 'and')
# ('buy', 'and', 'sell')
# ('and', 'sell', 'energy')
# ('sell', 'energy', "''")
# ('energy', "''", '.')
# ("''", '.', 'Cnet.com')
# ('.', 'Cnet.com', '.')
# ('Cnet.com', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'September')
# ('on', 'September', '19')
# ('September', '19', ',')
# ('19', ',', '2013')
# (',', '2013', '.')
# ('2013', '.', 'Retrieved')
# ('.', 'Retrieved', 'September')
# ('Retrieved', 'September', '23')
# ('September', '23', ',')
# ('23', ',', '2013')
# (',', '2013', '.')
# ('2013', '.', '^')
# ('.', '^', 'Todd')
# ('^', 'Todd', 'Woody')
# ('Todd', 'Woody', '(')
# ('Woody', '(', 'September')
# ('(', 'September', '18')
# ('September', '18', ',')
# ('18', ',', '2013')
# (',', '2013', ')')
# ('2013', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'is')
# ('Google', 'is', 'on')
# ('is', 'on', 'the')
# ('on', 'the', 'way')
# ('the', 'way', 'to')
# ('way', 'to', 'quietly')
# ('to', 'quietly', 'becoming')
# ('quietly', 'becoming', 'an')
# ('becoming', 'an', 'electric')
# ('an', 'electric', 'utility')
# ('electric', 'utility', "''")
# ('utility', "''", '.')
# ("''", '.', 'Quartz')
# ('.', 'Quartz', '.')
# ('Quartz', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'September')
# ('on', 'September', '21')
# ('September', '21', ',')
# ('21', ',', '2013')
# (',', '2013', '.')
# ('2013', '.', 'Retrieved')
# ('.', 'Retrieved', 'September')
# ('Retrieved', 'September', '23')
# ('September', '23', ',')
# ('23', ',', '2013')
# (',', '2013', '.')
# ('2013', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'buys')
# ('Google', 'buys', 'power')
# ('buys', 'power', 'from')
# ('power', 'from', 'Iowa')
# ('from', 'Iowa', 'wind')
# ('Iowa', 'wind', 'farm')
# ('wind', 'farm', "''")
# ('farm', "''", '.')
# ("''", '.', 'News.techworld.com')
# ('.', 'News.techworld.com', '.')
# ('News.techworld.com', '.', 'July')
# ('.', 'July', '21')
# ('July', '21', ',')
# ('21', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'February')
# ('on', 'February', '2')
# ('February', '2', ',')
# ('2', ',', '2012')
# (',', '2012', '.')
# ('2012', '.', 'Retrieved')
# ('.', 'Retrieved', 'October')
# ('Retrieved', 'October', '26')
# ('October', '26', ',')
# ('26', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', '^')
# ('.', '^', 'Hölzle')
# ('^', 'Hölzle', ',')
# ('Hölzle', ',', 'Urs')
# (',', 'Urs', '(')
# ('Urs', '(', 'December')
# ('(', 'December', '6')
# ('December', '6', ',')
# ('6', ',', '2016')
# (',', '2016', ')')
# ('2016', ')', '.')
# (')', '.', '``')
# ('.', '``', 'We')
# ('``', 'We', "'re")
# ('We', "'re", 'set')
# ("'re", 'set', 'to')
# ('set', 'to', 'reach')
# ('to', 'reach', '100')
# ('reach', '100', '%')
# ('100', '%', 'renewable')
# ('%', 'renewable', 'energy')
# ('renewable', 'energy', '—')
# ('energy', '—', 'and')
# ('—', 'and', 'it')
# ('and', 'it', "'s")
# ('it', "'s", 'just')
# ("'s", 'just', 'the')
# ('just', 'the', 'beginning')
# ('the', 'beginning', "''")
# ('beginning', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Keyword')
# ('The', 'Keyword', 'Google')
# ('Keyword', 'Google', 'Blog')
# ('Google', 'Blog', '.')
# ('Blog', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'December')
# ('on', 'December', '8')
# ('December', '8', ',')
# ('8', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'December')
# ('Retrieved', 'December', '8')
# ('December', '8', ',')
# ('8', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', '^')
# ('.', '^', 'Statt')
# ('^', 'Statt', ',')
# ('Statt', ',', 'Nick')
# (',', 'Nick', '(')
# ('Nick', '(', 'December')
# ('(', 'December', '6')
# ('December', '6', ',')
# ('6', ',', '2016')
# (',', '2016', ')')
# ('2016', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'just')
# ('Google', 'just', 'notched')
# ('just', 'notched', 'a')
# ('notched', 'a', 'big')
# ('a', 'big', 'victory')
# ('big', 'victory', 'in')
# ('victory', 'in', 'the')
# ('in', 'the', 'fight')
# ('the', 'fight', 'against')
# ('fight', 'against', 'climate')
# ('against', 'climate', 'change')
# ('climate', 'change', "''")
# ('change', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Verge')
# ('The', 'Verge', '.')
# ('Verge', '.', 'Vox')
# ('.', 'Vox', 'Media')
# ('Vox', 'Media', '.')
# ('Media', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'December')
# ('on', 'December', '8')
# ('December', '8', ',')
# ('8', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'December')
# ('Retrieved', 'December', '8')
# ('December', '8', ',')
# ('8', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', '^')
# ('.', '^', 'Etherington')
# ('^', 'Etherington', ',')
# ('Etherington', ',', 'Darrell')
# (',', 'Darrell', '(')
# ('Darrell', '(', 'December')
# ('(', 'December', '7')
# ('December', '7', ',')
# ('7', ',', '2016')
# (',', '2016', ')')
# ('2016', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'says')
# ('Google', 'says', 'it')
# ('says', 'it', 'will')
# ('it', 'will', 'hit')
# ('will', 'hit', '100')
# ('hit', '100', '%')
# ('100', '%', 'renewable')
# ('%', 'renewable', 'energy')
# ('renewable', 'energy', 'by')
# ('energy', 'by', '2017')
# ('by', '2017', "''")
# ('2017', "''", '.')
# ("''", '.', 'TechCrunch')
# ('.', 'TechCrunch', '.')
# ('TechCrunch', '.', 'AOL')
# ('.', 'AOL', '.')
# ('AOL', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'December')
# ('on', 'December', '7')
# ('December', '7', ',')
# ('7', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'December')
# ('Retrieved', 'December', '8')
# ('December', '8', ',')
# ('8', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', '^')
# ('.', '^', 'Donnelly')
# ('^', 'Donnelly', ',')
# ('Donnelly', ',', 'Grace')
# (',', 'Grace', '(')
# ('Grace', '(', 'November')
# ('(', 'November', '30')
# ('November', '30', ',')
# ('30', ',', '2017')
# (',', '2017', ')')
# ('2017', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'Just')
# ('Google', 'Just', 'Bought')
# ('Just', 'Bought', 'Enough')
# ('Bought', 'Enough', 'Wind')
# ('Enough', 'Wind', 'Power')
# ('Wind', 'Power', 'to')
# ('Power', 'to', 'Run')
# ('to', 'Run', '100')
# ('Run', '100', '%')
# ('100', '%', 'On')
# ('%', 'On', 'Renewable')
# ('On', 'Renewable', 'Energy')
# ('Renewable', 'Energy', "''")
# ('Energy', "''", '.')
# ("''", '.', 'Fortune')
# ('.', 'Fortune', '.')
# ('Fortune', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'December')
# ('on', 'December', '1')
# ('December', '1', ',')
# ('1', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', 'Retrieved')
# ('.', 'Retrieved', 'December')
# ('Retrieved', 'December', '1')
# ('December', '1', ',')
# ('1', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', 'correspondent')
# ('^', 'correspondent', ',')
# ('correspondent', ',', 'Jillian')
# (',', 'Jillian', 'Ambrose')
# ('Jillian', 'Ambrose', 'Energy')
# ('Ambrose', 'Energy', '(')
# ('Energy', '(', 'September')
# ('(', 'September', '20')
# ('September', '20', ',')
# ('20', ',', '2019')
# (',', '2019', ')')
# ('2019', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'signs')
# ('Google', 'signs', 'up')
# ('signs', 'up', 'to')
# ('up', 'to', '$')
# ('to', '$', '2bn')
# ('$', '2bn', 'wind')
# ('2bn', 'wind', 'and')
# ('wind', 'and', 'solar')
# ('and', 'solar', 'investment')
# ('solar', 'investment', "''")
# ('investment', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Guardian')
# ('The', 'Guardian', '.')
# ('Guardian', '.', 'ISSN')
# ('.', 'ISSN', '0261-3077')
# ('ISSN', '0261-3077', '.')
# ('0261-3077', '.', 'Retrieved')
# ('.', 'Retrieved', 'September')
# ('Retrieved', 'September', '25')
# ('September', '25', ',')
# ('25', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'Legum')
# ('^', 'Legum', ',')
# ('Legum', ',', 'Judd')
# (',', 'Judd', '.')
# ('Judd', '.', '``')
# ('.', '``', 'These')
# ('``', 'These', 'corporations')
# ('These', 'corporations', 'are')
# ('corporations', 'are', 'quietly')
# ('are', 'quietly', 'bankrolling')
# ('quietly', 'bankrolling', 'Congress')
# ('bankrolling', 'Congress', "'")
# ('Congress', "'", 'top')
# ("'", 'top', 'climate')
# ('top', 'climate', 'denier')
# ('climate', 'denier', "''")
# ('denier', "''", '.')
# ("''", '.', 'popular.info')
# ('.', 'popular.info', '.')
# ('popular.info', '.', 'Retrieved')
# ('.', 'Retrieved', 'February')
# ('Retrieved', 'February', '7')
# ('February', '7', ',')
# ('7', ',', '2020')
# (',', '2020', '.')
# ('2020', '.', '^')
# ('.', '^', 'Kirchgaessner')
# ('^', 'Kirchgaessner', ',')
# ('Kirchgaessner', ',', 'Stephanie')
# (',', 'Stephanie', '(')
# ('Stephanie', '(', 'October')
# ('(', 'October', '11')
# ('October', '11', ',')
# ('11', ',', '2019')
# (',', '2019', ')')
# ('2019', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Revealed')
# ('``', 'Revealed', ':')
# ('Revealed', ':', 'Google')
# (':', 'Google', 'made')
# ('Google', 'made', 'large')
# ('made', 'large', 'contributions')
# ('large', 'contributions', 'to')
# ('contributions', 'to', 'climate')
# ('to', 'climate', 'change')
# ('climate', 'change', 'deniers')
# ('change', 'deniers', "''")
# ('deniers', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Guardian')
# ('The', 'Guardian', '.')
# ('Guardian', '.', 'ISSN')
# ('.', 'ISSN', '0261-3077')
# ('ISSN', '0261-3077', '.')
# ('0261-3077', '.', 'Retrieved')
# ('.', 'Retrieved', 'February')
# ('Retrieved', 'February', '7')
# ('February', '7', ',')
# ('7', ',', '2020')
# (',', '2020', '.')
# ('2020', '.', '^')
# ('.', '^', 'Kirchgaessner')
# ('^', 'Kirchgaessner', ',')
# ('Kirchgaessner', ',', 'Stephanie')
# (',', 'Stephanie', '(')
# ('Stephanie', '(', 'October')
# ('(', 'October', '11')
# ('October', '11', ',')
# ('11', ',', '2019')
# (',', '2019', ')')
# ('2019', ')', '.')
# (')', '.', '``')
# ('.', '``', 'The')
# ('``', 'The', 'obscure')
# ('The', 'obscure', 'law')
# ('obscure', 'law', 'that')
# ('law', 'that', 'explains')
# ('that', 'explains', 'why')
# ('explains', 'why', 'Google')
# ('why', 'Google', 'backs')
# ('Google', 'backs', 'climate')
# ('backs', 'climate', 'deniers')
# ('climate', 'deniers', "''")
# ('deniers', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Guardian')
# ('The', 'Guardian', '.')
# ('Guardian', '.', 'ISSN')
# ('.', 'ISSN', '0261-3077')
# ('ISSN', '0261-3077', '.')
# ('0261-3077', '.', 'Retrieved')
# ('.', 'Retrieved', 'February')
# ('Retrieved', 'February', '7')
# ('February', '7', ',')
# ('7', ',', '2020')
# (',', '2020', '.')
# ('2020', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'About')
# ('``', 'About', 'the')
# ('About', 'the', 'Foundation')
# ('the', 'Foundation', "''")
# ('Foundation', "''", '.')
# ("''", '.', 'Google')
# ('.', 'Google', ',')
# ('Google', ',', 'Inc.')
# (',', 'Inc.', 'Archived')
# ('Inc.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'July')
# ('on', 'July', '14')
# ('July', '14', ',')
# ('14', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', 'Retrieved')
# ('.', 'Retrieved', 'July')
# ('Retrieved', 'July', '16')
# ('July', '16', ',')
# ('16', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', '^')
# ('.', '^', 'Hafner')
# ('^', 'Hafner', ',')
# ('Hafner', ',', 'Katie')
# (',', 'Katie', '(')
# ('Katie', '(', 'September')
# ('(', 'September', '14')
# ('September', '14', ',')
# ('14', ',', '2006')
# (',', '2006', ')')
# ('2006', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Philanthropy')
# ('``', 'Philanthropy', 'Google')
# ('Philanthropy', 'Google', "'s")
# ('Google', "'s", 'Way')
# ("'s", 'Way', ':')
# ('Way', ':', 'Not')
# (':', 'Not', 'the')
# ('Not', 'the', 'Usual')
# ('the', 'Usual', "''")
# ('Usual', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'New')
# ('The', 'New', 'York')
# ('New', 'York', 'Times')
# ('York', 'Times', '.')
# ('Times', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'July')
# ('on', 'July', '23')
# ('July', '23', ',')
# ('23', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '9')
# ('March', '9', ',')
# ('9', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', 'Helft')
# ('^', 'Helft', ',')
# ('Helft', ',', 'Miguel')
# (',', 'Miguel', '(')
# ('Miguel', '(', 'February')
# ('(', 'February', '23')
# ('February', '23', ',')
# ('23', ',', '2009')
# (',', '2009', ')')
# ('2009', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'Chief')
# ('Google', 'Chief', 'for')
# ('Chief', 'for', 'Charity')
# ('for', 'Charity', 'Steps')
# ('Charity', 'Steps', 'Down')
# ('Steps', 'Down', 'on')
# ('Down', 'on', 'Revamp')
# ('on', 'Revamp', "''")
# ('Revamp', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'New')
# ('The', 'New', 'York')
# ('New', 'York', 'Times')
# ('York', 'Times', '.')
# ('Times', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'April')
# ('on', 'April', '22')
# ('April', '22', ',')
# ('22', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '9')
# ('March', '9', ',')
# ('9', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Project')
# ('``', 'Project', '10')
# ('Project', '10', 'to')
# ('10', 'to', 'the')
# ('to', 'the', '100th')
# ('the', '100th', "''")
# ('100th', "''", '.')
# ("''", '.', 'Google')
# ('.', 'Google', ',')
# ('Google', ',', 'Inc.')
# (',', 'Inc.', 'Archived')
# ('Inc.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'June')
# ('on', 'June', '12')
# ('June', '12', ',')
# ('12', ',', '2009')
# (',', '2009', '.')
# ('2009', '.', 'Retrieved')
# ('.', 'Retrieved', 'July')
# ('Retrieved', 'July', '16')
# ('July', '16', ',')
# ('16', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', '^')
# ('.', '^', 'Van')
# ('^', 'Van', 'Burskirk')
# ('Van', 'Burskirk', ',')
# ('Burskirk', ',', 'Elliot')
# (',', 'Elliot', '(')
# ('Elliot', '(', 'June')
# ('(', 'June', '28')
# ('June', '28', ',')
# ('28', ',', '2010')
# (',', '2010', ')')
# ('2010', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'Struggles')
# ('Google', 'Struggles', 'to')
# ('Struggles', 'to', 'Give')
# ('to', 'Give', 'Away')
# ('Give', 'Away', '$')
# ('Away', '$', '10')
# ('$', '10', 'million')
# ('10', 'million', "''")
# ('million', "''", '.')
# ("''", '.', 'Wired')
# ('.', 'Wired', '.')
# ('Wired', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'August')
# ('on', 'August', '31')
# ('August', '31', ',')
# ('31', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', 'Retrieved')
# ('.', 'Retrieved', 'September')
# ('Retrieved', 'September', '26')
# ('September', '26', ',')
# ('26', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', '^')
# ('.', '^', 'Twohill')
# ('^', 'Twohill', ',')
# ('Twohill', ',', 'Lorraine')
# (',', 'Lorraine', '(')
# ('Lorraine', '(', 'September')
# ('(', 'September', '24')
# ('September', '24', ',')
# ('24', ',', '2010')
# (',', '2010', ')')
# ('2010', ')', '.')
# (')', '.', '``')
# ('.', '``', '$')
# ('``', '$', '10')
# ('$', '10', 'million')
# ('10', 'million', 'for')
# ('million', 'for', 'Project')
# ('for', 'Project', '10^100')
# ('Project', '10^100', 'winners')
# ('10^100', 'winners', "''")
# ('winners', "''", '.')
# ("''", '.', 'Google')
# ('.', 'Google', ',')
# ('Google', ',', 'Inc.')
# (',', 'Inc.', 'Archived')
# ('Inc.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'September')
# ('on', 'September', '26')
# ('September', '26', ',')
# ('26', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', 'Retrieved')
# ('.', 'Retrieved', 'September')
# ('Retrieved', 'September', '26')
# ('September', '26', ',')
# ('26', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', '^')
# ('.', '^', 'The')
# ('^', 'The', '2007')
# ('The', '2007', 'Archived')
# ('2007', 'Archived', 'November')
# ('Archived', 'November', '20')
# ('November', '20', ',')
# ('20', ',', '2018')
# (',', '2018', ',')
# ('2018', ',', 'at')
# (',', 'at', 'the')
# ('at', 'the', 'Wayback')
# ('the', 'Wayback', 'Machine')
# ('Wayback', 'Machine', 'Julia')
# ('Machine', 'Julia', 'Robinson')
# ('Julia', 'Robinson', 'Mathematics')
# ('Robinson', 'Mathematics', 'Festivalat')
# ('Mathematics', 'Festivalat', 'Google')
# ('Festivalat', 'Google', 'was')
# ('Google', 'was', 'the')
# ('was', 'the', 'founding')
# ('the', 'founding', 'of')
# ('founding', 'of', 'this')
# ('of', 'this', 'event')
# ('this', 'event', 'for')
# ('event', 'for', 'middle')
# ('for', 'middle', 'school')
# ('middle', 'school', 'and')
# ('school', 'and', 'high')
# ('and', 'high', 'school')
# ('high', 'school', 'students')
# ('school', 'students', '.')
# ('students', '.', 'video')
# ('.', 'video', '^')
# ('video', '^', 'Duffy')
# ('^', 'Duffy', ',')
# ('Duffy', ',', 'Jill')
# (',', 'Jill', '(')
# ('Jill', '(', 'January')
# ('(', 'January', '21')
# ('January', '21', ',')
# ('21', ',', '2011')
# (',', '2011', ')')
# ('2011', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Mathletes')
# ('``', 'Mathletes', 'Receive')
# ('Mathletes', 'Receive', '€1M')
# ('Receive', '€1M', 'Donation')
# ('€1M', 'Donation', 'from')
# ('Donation', 'from', 'Google')
# ('from', 'Google', "''")
# ('Google', "''", '.')
# ("''", '.', 'PC')
# ('.', 'PC', 'Magazine')
# ('PC', 'Magazine', '.')
# ('Magazine', '.', 'Ziff')
# ('.', 'Ziff', 'Davis')
# ('Ziff', 'Davis', '.')
# ('Davis', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'March')
# ('on', 'March', '23')
# ('March', '23', ',')
# ('23', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '23')
# ('March', '23', ',')
# ('23', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'donating')
# ('Google', 'donating', '1')
# ('donating', '1', 'million')
# ('1', 'million', 'euros')
# ('million', 'euros', 'to')
# ('euros', 'to', 'IMO')
# ('to', 'IMO', "''")
# ('IMO', "''", '.')
# ("''", '.', 'January')
# ('.', 'January', '20')
# ('January', '20', ',')
# ('20', ',', '2011')
# (',', '2011', '.')
# ('2011', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'July')
# ('on', 'July', '24')
# ('July', '24', ',')
# ('24', ',', '2011')
# (',', '2011', '.')
# ('2011', '.', 'Retrieved')
# ('.', 'Retrieved', 'February')
# ('Retrieved', 'February', '4')
# ('February', '4', ',')
# ('4', ',', '2011')
# (',', '2011', '.')
# ('2011', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'launches')
# ('Google', 'launches', "'Legalise")
# ('launches', "'Legalise", 'Love')
# ("'Legalise", 'Love', "'")
# ('Love', "'", 'gay')
# ("'", 'gay', 'rights')
# ('gay', 'rights', 'campaign')
# ('rights', 'campaign', "''")
# ('campaign', "''", '.')
# ("''", '.', 'PinkNews.co.uk')
# ('.', 'PinkNews.co.uk', '.')
# ('PinkNews.co.uk', '.', 'July')
# ('.', 'July', '8')
# ('July', '8', ',')
# ('8', ',', '2012')
# (',', '2012', '.')
# ('2012', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'August')
# ('on', 'August', '19')
# ('August', '19', ',')
# ('19', ',', '2014')
# (',', '2014', '.')
# ('2014', '.', 'Retrieved')
# ('.', 'Retrieved', 'September')
# ('Retrieved', 'September', '9')
# ('September', '9', ',')
# ('9', ',', '2014')
# (',', '2014', '.')
# ('2014', '.', '^')
# ('.', '^', 'Drucker')
# ('^', 'Drucker', ',')
# ('Drucker', ',', 'Jesse')
# (',', 'Jesse', '(')
# ('Jesse', '(', 'October')
# ('(', 'October', '21')
# ('October', '21', ',')
# ('21', ',', '2010')
# (',', '2010', ')')
# ('2010', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', '2.4')
# ('Google', '2.4', '%')
# ('2.4', '%', 'Rate')
# ('%', 'Rate', 'Shows')
# ('Rate', 'Shows', 'How')
# ('Shows', 'How', '$')
# ('How', '$', '60')
# ('$', '60', 'Billion')
# ('60', 'Billion', 'Is')
# ('Billion', 'Is', 'Lost')
# ('Is', 'Lost', 'to')
# ('Lost', 'to', 'Tax')
# ('to', 'Tax', 'Loopholes')
# ('Tax', 'Loopholes', "''")
# ('Loopholes', "''", '.')
# ("''", '.', 'Bloomberg')
# ('.', 'Bloomberg', 'Businessweek')
# ('Bloomberg', 'Businessweek', '.')
# ('Businessweek', '.', 'Bloomberg')
# ('.', 'Bloomberg', 'L.P.')
# ('Bloomberg', 'L.P.', 'Archived')
# ('L.P.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'September')
# ('on', 'September', '22')
# ('September', '22', ',')
# ('22', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'January')
# ('Retrieved', 'January', '22')
# ('January', '22', ',')
# ('22', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '(')
# ('.', '(', 'subscription')
# ('(', 'subscription', 'required')
# ('subscription', 'required', ')')
# ('required', ')', '^')
# (')', '^', '``')
# ('^', '``', 'The')
# ('``', 'The', 'Case')
# ('The', 'Case', 'Against')
# ('Case', 'Against', 'Google')
# ('Against', 'Google', "''")
# ('Google', "''", '.')
# ("''", '.', 'nytimes.com')
# ('.', 'nytimes.com', '.')
# ('nytimes.com', '.', 'February')
# ('.', 'February', '20')
# ('February', '20', ',')
# ('20', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'March')
# ('on', 'March', '19')
# ('March', '19', ',')
# ('19', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '21')
# ('March', '21', ',')
# ('21', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'ranked')
# ('Google', 'ranked', "'worst")
# ('ranked', "'worst", "'")
# ("'worst", "'", 'on')
# ("'", 'on', 'privacy')
# ('on', 'privacy', "''")
# ('privacy', "''", '.')
# ("''", '.', 'BBC')
# ('.', 'BBC', 'News')
# ('BBC', 'News', '.')
# ('News', '.', 'June')
# ('.', 'June', '11')
# ('June', '11', ',')
# ('11', ',', '2007')
# (',', '2007', '.')
# ('2007', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'October')
# ('on', 'October', '20')
# ('October', '20', ',')
# ('20', ',', '2012')
# (',', '2012', '.')
# ('2012', '.', 'Retrieved')
# ('.', 'Retrieved', 'April')
# ('Retrieved', 'April', '30')
# ('April', '30', ',')
# ('30', ',', '2010')
# (',', '2010', '.')
# ('2010', '.', '^')
# ('.', '^', 'Rosen')
# ('^', 'Rosen', ',')
# ('Rosen', ',', 'Jeffrey')
# (',', 'Jeffrey', '(')
# ('Jeffrey', '(', 'November')
# ('(', 'November', '28')
# ('November', '28', ',')
# ('28', ',', '2008')
# (',', '2008', ')')
# ('2008', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', "'s")
# ('Google', "'s", 'Gatekeepers')
# ("'s", 'Gatekeepers', "''")
# ('Gatekeepers', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'New')
# ('The', 'New', 'York')
# ('New', 'York', 'Times')
# ('York', 'Times', '.')
# ('Times', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'February')
# ('on', 'February', '28')
# ('February', '28', ',')
# ('28', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '9')
# ('March', '9', ',')
# ('9', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'censors')
# ('Google', 'censors', 'itself')
# ('censors', 'itself', 'for')
# ('itself', 'for', 'China')
# ('for', 'China', "''")
# ('China', "''", '.')
# ("''", '.', 'BBC')
# ('.', 'BBC', 'News')
# ('BBC', 'News', '.')
# ('News', '.', 'January')
# ('.', 'January', '25')
# ('January', '25', ',')
# ('25', ',', '2006')
# (',', '2006', '.')
# ('2006', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'November')
# ('on', 'November', '19')
# ('November', '19', ',')
# ('19', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Retrieved')
# ('.', 'Retrieved', 'August')
# ('Retrieved', 'August', '4')
# ('August', '4', ',')
# ('4', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'Plans')
# ('Google', 'Plans', 'to')
# ('Plans', 'to', 'Launch')
# ('to', 'Launch', 'Censored')
# ('Launch', 'Censored', 'Search')
# ('Censored', 'Search', 'Engine')
# ('Search', 'Engine', 'in')
# ('Engine', 'in', 'China')
# ('in', 'China', ',')
# ('China', ',', 'Leaked')
# (',', 'Leaked', 'Documents')
# ('Leaked', 'Documents', 'Reveal')
# ('Documents', 'Reveal', '·')
# ('Reveal', '·', 'Ryan')
# ('·', 'Ryan', 'Gallagher')
# ('Ryan', 'Gallagher', "''")
# ('Gallagher', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Intercept')
# ('The', 'Intercept', '.')
# ('Intercept', '.', 'August')
# ('.', 'August', '1')
# ('August', '1', ',')
# ('1', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'August')
# ('on', 'August', '1')
# ('August', '1', ',')
# ('1', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Retrieved')
# ('.', 'Retrieved', 'August')
# ('Retrieved', 'August', '4')
# ('August', '4', ',')
# ('4', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', 'Disis')
# ('^', 'Disis', ',')
# ('Disis', ',', 'Jill')
# (',', 'Jill', '(')
# ('Jill', '(', 'September')
# ('(', 'September', '26')
# ('September', '26', ',')
# ('26', ',', '2018')
# (',', '2018', ')')
# ('2018', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'grilled')
# ('Google', 'grilled', 'over')
# ('grilled', 'over', "'Project")
# ('over', "'Project", 'Dragonfly')
# ("'Project", 'Dragonfly', "'")
# ('Dragonfly', "'", 'at')
# ("'", 'at', 'Senate')
# ('at', 'Senate', 'hearing')
# ('Senate', 'hearing', 'on')
# ('hearing', 'on', 'data')
# ('on', 'data', 'privacy')
# ('data', 'privacy', "''")
# ('privacy', "''", '.')
# ("''", '.', 'CNN')
# ('.', 'CNN', '.')
# ('CNN', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'September')
# ('on', 'September', '26')
# ('September', '26', ',')
# ('26', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', 'Gallagher')
# ('^', 'Gallagher', ',')
# ('Gallagher', ',', 'Ryan')
# (',', 'Ryan', '(')
# ('Ryan', '(', 'December')
# ('(', 'December', '17')
# ('December', '17', ',')
# ('17', ',', '2018')
# (',', '2018', ')')
# ('2018', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', "'s")
# ('Google', "'s", 'Secret')
# ("'s", 'Secret', 'China')
# ('Secret', 'China', 'Project')
# ('China', 'Project', '``')
# ('Project', '``', 'Effectively')
# ('``', 'Effectively', 'Ended')
# ('Effectively', 'Ended', "''")
# ('Ended', "''", 'After')
# ("''", 'After', 'Internal')
# ('After', 'Internal', 'Confrontation')
# ('Internal', 'Confrontation', "''")
# ('Confrontation', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Intercept')
# ('The', 'Intercept', '.')
# ('Intercept', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'March')
# ('on', 'March', '21')
# ('March', '21', ',')
# ('21', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Retrieved')
# ('.', 'Retrieved', 'December')
# ('Retrieved', 'December', '17')
# ('December', '17', ',')
# ('17', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Edward')
# ('``', 'Edward', 'Snowden')
# ('Edward', 'Snowden', ':')
# ('Snowden', ':', 'Leaks')
# (':', 'Leaks', 'that')
# ('Leaks', 'that', 'exposed')
# ('that', 'exposed', 'US')
# ('exposed', 'US', 'spy')
# ('US', 'spy', 'programme')
# ('spy', 'programme', "''")
# ('programme', "''", '.')
# ("''", '.', 'BBC')
# ('.', 'BBC', 'News')
# ('BBC', 'News', '.')
# ('News', '.', 'January')
# ('.', 'January', '17')
# ('January', '17', ',')
# ('17', ',', '2014')
# (',', '2014', '.')
# ('2014', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'March')
# ('on', 'March', '20')
# ('March', '20', ',')
# ('20', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '25')
# ('March', '25', ',')
# ('25', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', 'Greenwald')
# ('^', 'Greenwald', ',')
# ('Greenwald', ',', 'Glenn')
# (',', 'Glenn', ';')
# ('Glenn', ';', 'MacAskill')
# (';', 'MacAskill', ',')
# ('MacAskill', ',', 'Ewen')
# (',', 'Ewen', '(')
# ('Ewen', '(', 'June')
# ('(', 'June', '7')
# ('June', '7', ',')
# ('7', ',', '2013')
# (',', '2013', ')')
# ('2013', ')', '.')
# (')', '.', '``')
# ('.', '``', 'NSA')
# ('``', 'NSA', 'Prism')
# ('NSA', 'Prism', 'program')
# ('Prism', 'program', 'taps')
# ('program', 'taps', 'in')
# ('taps', 'in', 'to')
# ('in', 'to', 'user')
# ('to', 'user', 'data')
# ('user', 'data', 'of')
# ('data', 'of', 'Apple')
# ('of', 'Apple', ',')
# ('Apple', ',', 'Google')
# (',', 'Google', 'and')
# ('Google', 'and', 'others')
# ('and', 'others', "''")
# ('others', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Guardian')
# ('The', 'Guardian', '.')
# ('Guardian', '.', 'Guardian')
# ('.', 'Guardian', 'Media')
# ('Guardian', 'Media', 'Group')
# ('Media', 'Group', '.')
# ('Group', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'August')
# ('on', 'August', '18')
# ('August', '18', ',')
# ('18', ',', '2006')
# (',', '2006', '.')
# ('2006', '.', 'Retrieved')
# ('.', 'Retrieved', 'March')
# ('Retrieved', 'March', '25')
# ('March', '25', ',')
# ('25', ',', '2017')
# (',', '2017', '.')
# ('2017', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'employees')
# ('Google', 'employees', 'revolt')
# ('employees', 'revolt', ',')
# ('revolt', ',', 'say')
# (',', 'say', 'company')
# ('say', 'company', 'should')
# ('company', 'should', 'shut')
# ('should', 'shut', 'down')
# ('shut', 'down', 'military')
# ('down', 'military', 'drone')
# ('military', 'drone', 'project')
# ('drone', 'project', 'Archived')
# ('project', 'Archived', 'April')
# ('Archived', 'April', '8')
# ('April', '8', ',')
# ('8', ',', '2018')
# (',', '2018', ',')
# ('2018', ',', 'at')
# (',', 'at', 'the')
# ('at', 'the', 'Wayback')
# ('the', 'Wayback', 'Machine')
# ('Wayback', 'Machine', "''")
# ('Machine', "''", '.')
# ("''", '.', 'Ars')
# ('.', 'Ars', 'Technica')
# ('Ars', 'Technica', '.')
# ('Technica', '.', 'April')
# ('.', 'April', '4')
# ('April', '4', ',')
# ('4', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Google')
# ('``', 'Google', 'staff')
# ('Google', 'staff', 'protest')
# ('staff', 'protest', 'company')
# ('protest', 'company', "'s")
# ('company', "'s", 'involvement')
# ("'s", 'involvement', 'with')
# ('involvement', 'with', 'Pentagon')
# ('with', 'Pentagon', 'drones')
# ('Pentagon', 'drones', 'programme')
# ('drones', 'programme', 'Archived')
# ('programme', 'Archived', 'April')
# ('Archived', 'April', '9')
# ('April', '9', ',')
# ('9', ',', '2018')
# (',', '2018', ',')
# ('2018', ',', 'at')
# (',', 'at', 'the')
# ('at', 'the', 'Wayback')
# ('the', 'Wayback', 'Machine')
# ('Wayback', 'Machine', "''")
# ('Machine', "''", '.')
# ("''", '.', 'The')
# ('.', 'The', 'Independent')
# ('The', 'Independent', '.')
# ('Independent', '.', 'April')
# ('.', 'April', '4')
# ('April', '4', ',')
# ('4', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', 'Wakabayashi')
# ('^', 'Wakabayashi', ',')
# ('Wakabayashi', ',', 'Daisuke')
# (',', 'Daisuke', ';')
# ('Daisuke', ';', 'Shane')
# (';', 'Shane', ',')
# ('Shane', ',', 'Scott')
# (',', 'Scott', '(')
# ('Scott', '(', 'June')
# ('(', 'June', '1')
# ('June', '1', ',')
# ('1', ',', '2018')
# (',', '2018', ')')
# ('2018', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', 'Will')
# ('Google', 'Will', 'Not')
# ('Will', 'Not', 'Renew')
# ('Not', 'Renew', 'Pentagon')
# ('Renew', 'Pentagon', 'Contract')
# ('Pentagon', 'Contract', 'That')
# ('Contract', 'That', 'Upset')
# ('That', 'Upset', 'Employees')
# ('Upset', 'Employees', "''")
# ('Employees', "''", '.')
# ("''", '.', 'nytimes.com')
# ('.', 'nytimes.com', '.')
# ('nytimes.com', '.', 'The')
# ('.', 'The', 'New')
# ('The', 'New', 'York')
# ('New', 'York', 'Times')
# ('York', 'Times', 'Company')
# ('Times', 'Company', '.')
# ('Company', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'October')
# ('on', 'October', '16')
# ('October', '16', ',')
# ('16', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', 'Retrieved')
# ('.', 'Retrieved', 'October')
# ('Retrieved', 'October', '16')
# ('October', '16', ',')
# ('16', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '^')
# ('.', '^', '``')
# ('^', '``', 'Thousands')
# ('``', 'Thousands', 'of')
# ('Thousands', 'of', 'Reddit')
# ('of', 'Reddit', 'users')
# ('Reddit', 'users', 'are')
# ('users', 'are', 'trying')
# ('are', 'trying', 'to')
# ('trying', 'to', 'delete')
# ('to', 'delete', 'Google')
# ('delete', 'Google', 'from')
# ('Google', 'from', 'their')
# ('from', 'their', 'lives')
# ('their', 'lives', ',')
# ('lives', ',', 'but')
# (',', 'but', 'they')
# ('but', 'they', "'re")
# ('they', "'re", 'finding')
# ("'re", 'finding', 'it')
# ('finding', 'it', 'impossible')
# ('it', 'impossible', 'because')
# ('impossible', 'because', 'Google')
# ('because', 'Google', 'is')
# ('Google', 'is', 'everywhere')
# ('is', 'everywhere', "''")
# ('everywhere', "''", '.')
# ("''", '.', 'March')
# ('.', 'March', '23')
# ('March', '23', ',')
# ('23', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'March')
# ('on', 'March', '25')
# ('March', '25', ',')
# ('25', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Retrieved')
# ('.', 'Retrieved', 'April')
# ('Retrieved', 'April', '24')
# ('April', '24', ',')
# ('24', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'Kan')
# ('^', 'Kan', ',')
# ('Kan', ',', 'By')
# (',', 'By', 'Michael')
# ('By', 'Michael', ';')
# ('Michael', ';', 'July')
# (';', 'July', '25')
# ('July', '25', ',')
# ('25', ',', '2018')
# (',', '2018', '12:39PM')
# ('2018', '12:39PM', 'EST')
# ('12:39PM', 'EST', ';')
# ('EST', ';', 'July')
# (';', 'July', '25')
# ('July', '25', ',')
# ('25', ',', '2018')
# (',', '2018', '.')
# ('2018', '.', '``')
# ('.', '``', 'Mozilla')
# ('``', 'Mozilla', 'Developer')
# ('Mozilla', 'Developer', 'Claims')
# ('Developer', 'Claims', 'Google')
# ('Claims', 'Google', 'Is')
# ('Google', 'Is', 'Slowing')
# ('Is', 'Slowing', 'YouTube')
# ('Slowing', 'YouTube', 'on')
# ('YouTube', 'on', 'Firefox')
# ('on', 'Firefox', "''")
# ('Firefox', "''", '.')
# ("''", '.', 'PCMAG')
# ('.', 'PCMAG', '.')
# ('PCMAG', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'August')
# ('on', 'August', '13')
# ('August', '13', ',')
# ('13', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Retrieved')
# ('.', 'Retrieved', 'August')
# ('Retrieved', 'August', '13')
# ('August', '13', ',')
# ('13', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'Cimpanu')
# ('^', 'Cimpanu', ',')
# ('Cimpanu', ',', 'Catalin')
# (',', 'Catalin', '.')
# ('Catalin', '.', '``')
# ('.', '``', 'Former')
# ('``', 'Former', 'Mozilla')
# ('Former', 'Mozilla', 'exec')
# ('Mozilla', 'exec', ':')
# ('exec', ':', 'Google')
# (':', 'Google', 'has')
# ('Google', 'has', 'sabotaged')
# ('has', 'sabotaged', 'Firefox')
# ('sabotaged', 'Firefox', 'for')
# ('Firefox', 'for', 'years')
# ('for', 'years', "''")
# ('years', "''", '.')
# ("''", '.', 'ZDNet')
# ('.', 'ZDNet', '.')
# ('ZDNet', '.', 'Archived')
# ('.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'August')
# ('on', 'August', '19')
# ('August', '19', ',')
# ('19', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', 'Retrieved')
# ('.', 'Retrieved', 'August')
# ('Retrieved', 'August', '13')
# ('August', '13', ',')
# ('13', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'Copeland')
# ('^', 'Copeland', ',')
# ('Copeland', ',', 'Rob')
# (',', 'Rob', '(')
# ('Rob', '(', 'November')
# ('(', 'November', '12')
# ('November', '12', ',')
# ('12', ',', '2019')
# (',', '2019', ')')
# ('2019', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', "'s")
# ('Google', "'s", "'Project")
# ("'s", "'Project", 'Nightingale')
# ("'Project", 'Nightingale', "'")
# ('Nightingale', "'", 'Triggers')
# ("'", 'Triggers', 'Federal')
# ('Triggers', 'Federal', 'Inquiry')
# ('Federal', 'Inquiry', "''")
# ('Inquiry', "''", '.')
# ("''", '.', 'Retrieved')
# ('.', 'Retrieved', 'November')
# ('Retrieved', 'November', '18')
# ('November', '18', ',')
# ('18', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'Copeland')
# ('^', 'Copeland', ',')
# ('Copeland', ',', 'Rob')
# (',', 'Rob', '(')
# ('Rob', '(', 'November')
# ('(', 'November', '11')
# ('November', '11', ',')
# ('11', ',', '2019')
# (',', '2019', ')')
# ('2019', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ('``', 'Google', "'s")
# ('Google', "'s", "'Project")
# ("'s", "'Project", 'Nightingale')
# ("'Project", 'Nightingale', "'")
# ('Nightingale', "'", 'Gathers')
# ("'", 'Gathers', 'Personal')
# ('Gathers', 'Personal', 'Health')
# ('Personal', 'Health', 'Data')
# ('Health', 'Data', 'on')
# ('Data', 'on', 'Millions')
# ('on', 'Millions', 'of')
# ('Millions', 'of', 'Americans')
# ('of', 'Americans', "''")
# ('Americans', "''", '.')
# ("''", '.', 'Retrieved')
# ('.', 'Retrieved', 'November')
# ('Retrieved', 'November', '17')
# ('November', '17', ',')
# ('17', ',', '2019')
# (',', '2019', '.')
# ('2019', '.', '^')
# ('.', '^', 'Rosenblatt')
# ('^', 'Rosenblatt', ',')
# ('Rosenblatt', ',', 'Joel')
# (',', 'Joel', '(')
# ('Joel', '(', 'March')
# ('(', 'March', '2')
# ('March', '2', ',')
# ('2', ',', '2015')
# (',', '2015', ')')
# ('2015', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Apple-Google')
# ('``', 'Apple-Google', '$')
# ('Apple-Google', '$', '415')
# ('$', '415', 'Million')
# ('415', 'Million', 'No-Poaching')
# ('Million', 'No-Poaching', 'Accord')
# ('No-Poaching', 'Accord', 'Wins')
# ('Accord', 'Wins', 'Approval')
# ('Wins', 'Approval', "''")
# ('Approval', "''", '.')
# ("''", '.', 'Bloomberg')
# ('.', 'Bloomberg', 'L.P.')
# ('Bloomberg', 'L.P.', 'Archived')
# ('L.P.', 'Archived', 'from')
# ('Archived', 'from', 'the')
# ('from', 'the', 'original')
# ('the', 'original', 'on')
# ('original', 'on', 'January')
# ('on', 'January', '30')
# ('January', '30', ',')
# ('30', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', 'Retrieved')
# ('.', 'Retrieved', 'January')
# ('Retrieved', 'January', '24')
# ('January', '24', ',')
# ('24', ',', '2016')
# (',', '2016', '.')
# ('2016', '.', '^')
# ('.', '^', 'Kelion')
# ('^', 'Kelion', ',')
# ('Kelion', ',', 'Leo')
# (',', 'Leo', '(')
# ('Leo', '(', 'June')
# ('(', 'June', '27')
# ('June', '27', ',')
# ('27', ',', '2017')
# (',', '2017', ')')
# ('2017', ')', '.')
# (')', '.', '``')
# ('.', '``', 'Google')
# ...
# (',', "''", 'limit')
# ("''", 'limit', "''")
# ('limit', "''", ':500')
# ("''", ':500', '}')
# (':500', '}', ',')
# ('}', ',', "''")
# (',', "''", 'unstrip-depth')
# ("''", 'unstrip-depth', "''")
# ('unstrip-depth', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', 'value')
# ('``', 'value', "''")
# ('value', "''", ':1')
# ("''", ':1', ',')
# (':1', ',', "''")
# (',', "''", 'limit')
# ("''", 'limit', "''")
# ('limit', "''", ':20')
# ("''", ':20', '}')
# (':20', '}', ',')
# ('}', ',', "''")
# (',', "''", 'unstrip-size')
# ("''", 'unstrip-size', "''")
# ('unstrip-size', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', 'value')
# ('``', 'value', "''")
# ('value', "''", ':987275')
# ("''", ':987275', ',')
# (':987275', ',', "''")
# (',', "''", 'limit')
# ("''", 'limit', "''")
# ('limit', "''", ':5000000')
# ("''", ':5000000', '}')
# (':5000000', '}', ',')
# ('}', ',', "''")
# (',', "''", 'entityaccesscount')
# ("''", 'entityaccesscount', "''")
# ('entityaccesscount', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', 'value')
# ('``', 'value', "''")
# ('value', "''", ':6')
# ("''", ':6', ',')
# (':6', ',', "''")
# (',', "''", 'limit')
# ("''", 'limit', "''")
# ('limit', "''", ':400')
# ("''", ':400', '}')
# (':400', '}', ',')
# ('}', ',', "''")
# (',', "''", 'timingprofile')
# ("''", 'timingprofile', "''")
# ('timingprofile', "''", ':')
# ("''", ':', '[')
# (':', '[', '``')
# ('[', '``', '100.00')
# ('``', '100.00', '%')
# ('100.00', '%', '4161.894')
# ('%', '4161.894', '1')
# ('4161.894', '1', '-total')
# ('1', '-total', "''")
# ('-total', "''", ',')
# ("''", ',', "''")
# (',', "''", '61.12')
# ("''", '61.12', '%')
# ('61.12', '%', '2543.620')
# ('%', '2543.620', '2')
# ('2543.620', '2', 'Template')
# ('2', 'Template', ':')
# ('Template', ':', 'Reflist')
# (':', 'Reflist', "''")
# ('Reflist', "''", ',')
# ("''", ',', "''")
# (',', "''", '34.09')
# ("''", '34.09', '%')
# ('34.09', '%', '1418.602')
# ('%', '1418.602', '209')
# ('1418.602', '209', 'Template')
# ('209', 'Template', ':')
# ('Template', ':', 'Cite_web')
# (':', 'Cite_web', "''")
# ('Cite_web', "''", ',')
# ("''", ',', "''")
# (',', "''", '14.57')
# ("''", '14.57', '%')
# ('14.57', '%', '606.189')
# ('%', '606.189', '1')
# ('606.189', '1', 'Template')
# ('1', 'Template', ':')
# ('Template', ':', 'Infobox_company')
# (':', 'Infobox_company', "''")
# ('Infobox_company', "''", ',')
# ("''", ',', "''")
# (',', "''", '14.04')
# ("''", '14.04', '%')
# ('14.04', '%', '584.332')
# ('%', '584.332', '1')
# ('584.332', '1', 'Template')
# ('1', 'Template', ':')
# ('Template', ':', 'Infobox')
# (':', 'Infobox', "''")
# ('Infobox', "''", ',')
# ("''", ',', "''")
# (',', "''", '11.88')
# ("''", '11.88', '%')
# ('11.88', '%', '494.280')
# ('%', '494.280', '68')
# ('494.280', '68', 'Template')
# ('68', 'Template', ':')
# ('Template', ':', 'Cite_news')
# (':', 'Cite_news', "''")
# ('Cite_news', "''", ',')
# ("''", ',', "''")
# (',', "''", '10.17')
# ("''", '10.17', '%')
# ('10.17', '%', '423.325')
# ('%', '423.325', '7')
# ('423.325', '7', 'Template')
# ('7', 'Template', ':')
# ('Template', ':', 'Wikidata')
# (':', 'Wikidata', "''")
# ('Wikidata', "''", ',')
# ("''", ',', "''")
# (',', "''", '5.61')
# ("''", '5.61', '%')
# ('5.61', '%', '233.280')
# ('%', '233.280', '1')
# ('233.280', '1', 'Template')
# ('1', 'Template', ':')
# ('Template', ':', 'Br_separated_entries')
# (':', 'Br_separated_entries', "''")
# ('Br_separated_entries', "''", ',')
# ("''", ',', "''")
# (',', "''", '3.24')
# ("''", '3.24', '%')
# ('3.24', '%', '135.041')
# ('%', '135.041', '10')
# ('135.041', '10', 'Template')
# ('10', 'Template', ':')
# ('Template', ':', 'Cite_journal')
# (':', 'Cite_journal', "''")
# ('Cite_journal', "''", ',')
# ("''", ',', "''")
# (',', "''", '3.00')
# ("''", '3.00', '%')
# ('3.00', '%', '124.827')
# ('%', '124.827', '17')
# ('124.827', '17', 'Template')
# ('17', 'Template', ':')
# ('Template', ':', 'Navbox')
# (':', 'Navbox', "''")
# ('Navbox', "''", ']')
# ("''", ']', '}')
# (']', '}', ',')
# ('}', ',', "''")
# (',', "''", 'scribunto')
# ("''", 'scribunto', "''")
# ('scribunto', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', 'limitreport-timeusage')
# ('``', 'limitreport-timeusage', "''")
# ('limitreport-timeusage', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', 'value')
# ('``', 'value', "''")
# ('value', "''", ':')
# ("''", ':', "''")
# (':', "''", '2.561')
# ("''", '2.561', "''")
# ('2.561', "''", ',')
# ("''", ',', "''")
# (',', "''", 'limit')
# ("''", 'limit', "''")
# ('limit', "''", ':')
# ("''", ':', "''")
# (':', "''", '10.000')
# ("''", '10.000', "''")
# ('10.000', "''", '}')
# ("''", '}', ',')
# ('}', ',', "''")
# (',', "''", 'limitreport-memusage')
# ("''", 'limitreport-memusage', "''")
# ('limitreport-memusage', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', 'value')
# ('``', 'value', "''")
# ('value', "''", ':18175116')
# ("''", ':18175116', ',')
# (':18175116', ',', "''")
# (',', "''", 'limit')
# ("''", 'limit', "''")
# ('limit', "''", ':52428800')
# ("''", ':52428800', '}')
# (':52428800', '}', ',')
# ('}', ',', "''")
# (',', "''", 'limitreport-logs')
# ("''", 'limitreport-logs', "''")
# ('limitreport-logs', "''", ':')
# ("''", ':', "''")
# (':', "''", 'table')
# ("''", 'table', '#')
# ('table', '#', '1')
# ('#', '1', '{')
# ('1', '{', '\\n')
# ('{', '\\n', '}')
# ('\\n', '}', '\\ntable')
# ('}', '\\ntable', '#')
# ('\\ntable', '#', '1')
# ('#', '1', '{')
# ('1', '{', '\\n')
# ('{', '\\n', '}')
# ('\\n', '}', '\\ntable')
# ('}', '\\ntable', '#')
# ('\\ntable', '#', '1')
# ('#', '1', '{')
# ('1', '{', '\\n')
# ('{', '\\n', '}')
# ('\\n', '}', '\\ntable')
# ('}', '\\ntable', '#')
# ('\\ntable', '#', '1')
# ('#', '1', '{')
# ('1', '{', '\\n')
# ('{', '\\n', '}')
# ('\\n', '}', '\\n')
# ('}', '\\n', "''")
# ('\\n', "''", ',')
# ("''", ',', "''")
# (',', "''", 'limitreport-profile')
# ("''", 'limitreport-profile', "''")
# ('limitreport-profile', "''", ':')
# ("''", ':', '[')
# (':', '[', '[')
# ('[', '[', '``')
# ('[', '``', 'Scribunto_LuaSandboxCallback')
# ('``', 'Scribunto_LuaSandboxCallback', ':')
# ('Scribunto_LuaSandboxCallback', ':', ':match')
# (':', ':match', "''")
# (':match', "''", ',')
# ("''", ',', "''")
# (',', "''", '420')
# ("''", '420', "''")
# ('420', "''", ',')
# ("''", ',', "''")
# (',', "''", '15.8')
# ("''", '15.8', "''")
# ('15.8', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', '?')
# ('``', '?', '``')
# ('?', '``', ',')
# ('``', ',', "''")
# (',', "''", '240')
# ("''", '240', "''")
# ('240', "''", ',')
# ("''", ',', "''")
# (',', "''", '9.0')
# ("''", '9.0', "''")
# ('9.0', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', 'recursiveClone')
# ('``', 'recursiveClone', '\\u003CmwInit.lua:41\\u003E')
# ('recursiveClone', '\\u003CmwInit.lua:41\\u003E', "''")
# ('\\u003CmwInit.lua:41\\u003E', "''", ',')
# ("''", ',', "''")
# (',', "''", '220')
# ("''", '220', "''")
# ('220', "''", ',')
# ("''", ',', "''")
# (',', "''", '8.3')
# ("''", '8.3', "''")
# ('8.3', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', 'dataWrapper')
# ('``', 'dataWrapper', '\\u003Cmw.lua:661\\u003E')
# ('dataWrapper', '\\u003Cmw.lua:661\\u003E', "''")
# ('\\u003Cmw.lua:661\\u003E', "''", ',')
# ("''", ',', "''")
# (',', "''", '200')
# ("''", '200', "''")
# ('200', "''", ',')
# ("''", ',', "''")
# (',', "''", '7.5')
# ("''", '7.5', "''")
# ('7.5', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', 'Scribunto_LuaSandboxCallback')
# ('``', 'Scribunto_LuaSandboxCallback', ':')
# ('Scribunto_LuaSandboxCallback', ':', ':getEntity')
# (':', ':getEntity', "''")
# (':getEntity', "''", ',')
# ("''", ',', "''")
# (',', "''", '160')
# ("''", '160', "''")
# ('160', "''", ',')
# ("''", ',', "''")
# (',', "''", '6.0')
# ("''", '6.0', "''")
# ('6.0', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', 'Scribunto_LuaSandboxCallback')
# ('``', 'Scribunto_LuaSandboxCallback', ':')
# ('Scribunto_LuaSandboxCallback', ':', ':find')
# (':', ':find', "''")
# (':find', "''", ',')
# ("''", ',', "''")
# (',', "''", '140')
# ("''", '140', "''")
# ('140', "''", ',')
# ("''", ',', "''")
# (',', "''", '5.3')
# ("''", '5.3', "''")
# ('5.3', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', '\\u003Cmw.lua:683\\u003E')
# ('``', '\\u003Cmw.lua:683\\u003E', "''")
# ('\\u003Cmw.lua:683\\u003E', "''", ',')
# ("''", ',', "''")
# (',', "''", '100')
# ("''", '100', "''")
# ('100', "''", ',')
# ("''", ',', "''")
# (',', "''", '3.8')
# ("''", '3.8', "''")
# ('3.8', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', 'Scribunto_LuaSandboxCallback')
# ('``', 'Scribunto_LuaSandboxCallback', ':')
# ('Scribunto_LuaSandboxCallback', ':', ':callParserFunction')
# (':', ':callParserFunction', "''")
# (':callParserFunction', "''", ',')
# ("''", ',', "''")
# (',', "''", '80')
# ("''", '80', "''")
# ('80', "''", ',')
# ("''", ',', "''")
# (',', "''", '3.0')
# ("''", '3.0', "''")
# ('3.0', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', 'Scribunto_LuaSandboxCallback')
# ('``', 'Scribunto_LuaSandboxCallback', ':')
# ('Scribunto_LuaSandboxCallback', ':', ':getExpandedArgument')
# (':', ':getExpandedArgument', "''")
# (':getExpandedArgument', "''", ',')
# ("''", ',', "''")
# (',', "''", '80')
# ("''", '80', "''")
# ('80', "''", ',')
# ("''", ',', "''")
# (',', "''", '3.0')
# ("''", '3.0', "''")
# ('3.0', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', 'Scribunto_LuaSandboxCallback')
# ('``', 'Scribunto_LuaSandboxCallback', ':')
# ('Scribunto_LuaSandboxCallback', ':', ':plain')
# (':', ':plain', "''")
# (':plain', "''", ',')
# ("''", ',', "''")
# (',', "''", '80')
# ("''", '80', "''")
# ('80', "''", ',')
# ("''", ',', "''")
# (',', "''", '3.0')
# ("''", '3.0', "''")
# ('3.0', "''", ']')
# ("''", ']', ',')
# (']', ',', '[')
# (',', '[', '``')
# ('[', '``', '[')
# ('``', '[', 'others')
# ('[', 'others', ']')
# ('others', ']', "''")
# (']', "''", ',')
# ("''", ',', "''")
# (',', "''", '940')
# ("''", '940', "''")
# ('940', "''", ',')
# ("''", ',', "''")
# (',', "''", '35.3')
# ("''", '35.3', "''")
# ('35.3', "''", ']')
# ("''", ']', ']')
# (']', ']', '}')
# (']', '}', ',')
# ('}', ',', "''")
# (',', "''", 'cachereport')
# ("''", 'cachereport', "''")
# ('cachereport', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', 'origin')
# ('``', 'origin', "''")
# ('origin', "''", ':')
# ("''", ':', "''")
# (':', "''", 'mw1241')
# ("''", 'mw1241', "''")
# ('mw1241', "''", ',')
# ("''", ',', "''")
# (',', "''", 'timestamp')
# ("''", 'timestamp', "''")
# ('timestamp', "''", ':')
# ("''", ':', "''")
# (':', "''", '20200305232510')
# ("''", '20200305232510', "''")
# ('20200305232510', "''", ',')
# ("''", ',', "''")
# (',', "''", 'ttl')
# ("''", 'ttl', "''")
# ('ttl', "''", ':2592000')
# ("''", ':2592000', ',')
# (':2592000', ',', "''")
# (',', "''", 'transientcontent')
# ("''", 'transientcontent', "''")
# ('transientcontent', "''", ':')
# ("''", ':', 'false')
# (':', 'false', '}')
# ('false', '}', '}')
# ('}', '}', '}')
# ('}', '}', ')')
# ('}', ')', ';')
# (')', ';', '}')
# (';', '}', ')')
# ('}', ')', ';')
# (')', ';', '{')
# (';', '{', '``')
# ('{', '``', '@')
# ('``', '@', 'context')
# ('@', 'context', "''")
# ('context', "''", ':')
# ("''", ':', "''")
# (':', "''", 'https')
# ("''", 'https', ':')
# ('https', ':', '\\/\\/schema.org')
# (':', '\\/\\/schema.org', "''")
# ('\\/\\/schema.org', "''", ',')
# ("''", ',', "''")
# (',', "''", '@')
# ("''", '@', 'type')
# ('@', 'type', "''")
# ('type', "''", ':')
# ("''", ':', "''")
# (':', "''", 'Article')
# ("''", 'Article', "''")
# ('Article', "''", ',')
# ("''", ',', "''")
# (',', "''", 'name')
# ("''", 'name', "''")
# ('name', "''", ':')
# ("''", ':', "''")
# (':', "''", 'Google')
# ("''", 'Google', "''")
# ('Google', "''", ',')
# ("''", ',', "''")
# (',', "''", 'url')
# ("''", 'url', "''")
# ('url', "''", ':')
# ("''", ':', "''")
# (':', "''", 'https')
# ("''", 'https', ':')
# ('https', ':', '\\/\\/en.wikipedia.org\\/wiki\\/Google')
# (':', '\\/\\/en.wikipedia.org\\/wiki\\/Google', "''")
# ('\\/\\/en.wikipedia.org\\/wiki\\/Google', "''", ',')
# ("''", ',', "''")
# (',', "''", 'sameAs')
# ("''", 'sameAs', "''")
# ('sameAs', "''", ':')
# ("''", ':', "''")
# (':', "''", 'http')
# ("''", 'http', ':')
# ('http', ':', '\\/\\/www.wikidata.org\\/entity\\/Q95')
# (':', '\\/\\/www.wikidata.org\\/entity\\/Q95', "''")
# ('\\/\\/www.wikidata.org\\/entity\\/Q95', "''", ',')
# ("''", ',', "''")
# (',', "''", 'mainEntity')
# ("''", 'mainEntity', "''")
# ('mainEntity', "''", ':')
# ("''", ':', "''")
# (':', "''", 'http')
# ("''", 'http', ':')
# ('http', ':', '\\/\\/www.wikidata.org\\/entity\\/Q95')
# (':', '\\/\\/www.wikidata.org\\/entity\\/Q95', "''")
# ('\\/\\/www.wikidata.org\\/entity\\/Q95', "''", ',')
# ("''", ',', "''")
# (',', "''", 'author')
# ("''", 'author', "''")
# ('author', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', '@')
# ('``', '@', 'type')
# ('@', 'type', "''")
# ('type', "''", ':')
# ("''", ':', "''")
# (':', "''", 'Organization')
# ("''", 'Organization', "''")
# ('Organization', "''", ',')
# ("''", ',', "''")
# (',', "''", 'name')
# ("''", 'name', "''")
# ('name', "''", ':')
# ("''", ':', "''")
# (':', "''", 'Contributors')
# ("''", 'Contributors', 'to')
# ('Contributors', 'to', 'Wikimedia')
# ('to', 'Wikimedia', 'projects')
# ('Wikimedia', 'projects', "''")
# ('projects', "''", '}')
# ("''", '}', ',')
# ('}', ',', "''")
# (',', "''", 'publisher')
# ("''", 'publisher', "''")
# ('publisher', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', '@')
# ('``', '@', 'type')
# ('@', 'type', "''")
# ('type', "''", ':')
# ("''", ':', "''")
# (':', "''", 'Organization')
# ("''", 'Organization', "''")
# ('Organization', "''", ',')
# ("''", ',', "''")
# (',', "''", 'name')
# ("''", 'name', "''")
# ('name', "''", ':')
# ("''", ':', "''")
# (':', "''", 'Wikimedia')
# ("''", 'Wikimedia', 'Foundation')
# ('Wikimedia', 'Foundation', ',')
# ('Foundation', ',', 'Inc.')
# (',', 'Inc.', "''")
# ('Inc.', "''", ',')
# ("''", ',', "''")
# (',', "''", 'logo')
# ("''", 'logo', "''")
# ('logo', "''", ':')
# ("''", ':', '{')
# (':', '{', '``')
# ('{', '``', '@')
# ('``', '@', 'type')
# ('@', 'type', "''")
# ('type', "''", ':')
# ("''", ':', "''")
# (':', "''", 'ImageObject')
# ("''", 'ImageObject', "''")
# ('ImageObject', "''", ',')
# ("''", ',', "''")
# (',', "''", 'url')
# ("''", 'url', "''")
# ('url', "''", ':')
# ("''", ':', "''")
# (':', "''", 'https')
# ("''", 'https', ':')
# ('https', ':', '\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png')
# (':', '\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png', "''")
# ('\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png', "''", '}')
# ("''", '}', '}')
# ('}', '}', ',')
# ('}', ',', "''")
# (',', "''", 'datePublished')
# ("''", 'datePublished', "''")
# ('datePublished', "''", ':')
# ("''", ':', "''")
# (':', "''", '2004-10-22T20:08:26Z')
# ("''", '2004-10-22T20:08:26Z', "''")
# ('2004-10-22T20:08:26Z', "''", ',')
# ("''", ',', "''")
# (',', "''", 'dateModified')
# ("''", 'dateModified', "''")
# ('dateModified', "''", ':')
# ("''", ':', "''")
# (':', "''", '2020-02-27T00:04:44Z')
# ("''", '2020-02-27T00:04:44Z', "''")
# ('2020-02-27T00:04:44Z', "''", ',')
# ("''", ',', "''")
# (',', "''", 'image')
# ("''", 'image', "''")
# ('image', "''", ':')
# ("''", ':', "''")
# (':', "''", 'https')
# ("''", 'https', ':')
# ('https', ':', '\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/3\\/32\\/Googleplex_HQ_')
# (':', '\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/3\\/32\\/Googleplex_HQ_', '%')
# ('\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/3\\/32\\/Googleplex_HQ_', '%', '28cropped')
# ('%', '28cropped', '%')
# ('28cropped', '%', '29.jpg')
# ('%', '29.jpg', "''")
# ('29.jpg', "''", ',')
# ("''", ',', "''")
# (',', "''", 'headline')
# ("''", 'headline', "''")
# ('headline', "''", ':')
# ("''", ':', "''")
# (':', "''", 'American')
# ("''", 'American', 'multinational')
# ('American', 'multinational', 'Internet')
# ('multinational', 'Internet', 'and')
# ('Internet', 'and', 'technology')
# ('and', 'technology', 'corporation')
# ('technology', 'corporation', "''")
# ('corporation', "''", '}')
# ("''", '}', '(')
# ('}', '(', 'RLQ=window.RLQ||')
# ('(', 'RLQ=window.RLQ||', '[')
# ('RLQ=window.RLQ||', '[', ']')
# ('[', ']', ')')
# (']', ')', '.push')
# (')', '.push', '(')
# ('.push', '(', 'function')
# ('(', 'function', '(')
# ('function', '(', ')')
# ('(', ')', '{')
# (')', '{', 'mw.config.set')
# ('{', 'mw.config.set', '(')
# ('mw.config.set', '(', '{')
# ('(', '{', '``')
# ('{', '``', 'wgBackendResponseTime')
# ('``', 'wgBackendResponseTime', "''")
# ('wgBackendResponseTime', "''", ':132')
# ("''", ':132', ',')
# (':132', ',', "''")
# (',', "''", 'wgHostname')
# ("''", 'wgHostname', "''")
# ('wgHostname', "''", ':')
# ("''", ':', "''")
# (':', "''", 'mw1401')
# ("''", 'mw1401', "''")
# ('mw1401', "''", '}')
# ("''", '}', ')')
# ('}', ')', ';')
# (')', ';', '}')
# (';', '}', ')')
# ('}', ')', ';')

# %%
nltk.download('maxent_ne_chunker')
from nltk import wordpunct_tokenize, pos_tag, ne_chunk

for i in wtokens:
    print(ne_chunk(pos_tag(wordpunct_tokenize(i))))
# Out:
# Streaming output truncated to the last 5000 lines.
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S May/NNP)
# (S 19/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S October/NNP)
# (S 17/CD)
# (S ,/,)
# (S 2006/CD)
# (S ./.)
# (S ^/NN)
# (S (ORGANIZATION McGrath/NN))
# (S ,/,)
# (S (GPE Jack/NNP))
# (S (/()
# (S May/NNP)
# (S 18/CD)
# (S ,/,)
# (S 2011/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S (GPE Green/JJ))
# (S (GPE Initiative/NN))
# (S :/:)
# (S Environmentally/RB)
# (S Conscious/JJ)
# (S (GPE Technology/NN))
# (S ''/'')
# (S ./.)
# (S TechnoBuffalo/NN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S October/NNP)
# (S 12/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S January/NNP)
# (S 22/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Glanz/NN))
# (S ,/,)
# (S (PERSON James/NNP))
# (S (/()
# (S September/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2011/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S Details/NNS)
# (S ,/,)
# (S and/CC)
# (S Defends/NNS)
# (S ,/,)
# (S Its/PRP$)
# (S Use/NN)
# (S of/IN)
# (S (GPE Electricity/NN))
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE New/NNP))
# (S (GPE York/NNP))
# (S Times/NNS)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 12/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 9/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Morrison/NN))
# (S ,/,)
# (S (GPE Scott/NN))
# (S ;/:)
# (S (GPE Sweet/NN))
# (S ,/,)
# (S (GPE Cassandra/NN))
# (S (/()
# (S May/NNP)
# (S 4/CD)
# (S ,/,)
# (S 2010/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S Invests/NNS)
# (S in/IN)
# (S Two/CD)
# (S Wind/IN)
# (S Farms/NNS)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Wall/NNP))
# (S (GPE Street/NNP))
# (S (GPE Journal/NNP))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S February/NNP)
# (S 13/CD)
# (S ,/,)
# (S 2015/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S November/NNP)
# (S 27/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S (GPE Energy/NNP))
# (S can/MD)
# (S now/RB)
# (S buy/VB)
# (S and/CC)
# (S sell/NN)
# (S energy/NN)
# (S ''/'')
# (S ./.)
# (S (GPE Cnet/NNP) ./. com/NN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S September/NNP)
# (S 19/CD)
# (S ,/,)
# (S 2013/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S September/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2013/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Todd/NN))
# (S (GPE Woody/NN))
# (S (/()
# (S September/NNP)
# (S 18/CD)
# (S ,/,)
# (S 2013/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S is/VBZ)
# (S on/IN)
# (S the/DT)
# (S way/NN)
# (S to/TO)
# (S quietly/RB)
# (S becoming/VBG)
# (S an/DT)
# (S electric/JJ)
# (S utility/NN)
# (S ''/'')
# (S ./.)
# (S (GPE Quartz/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S September/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2013/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S September/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2013/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S buys/NNS)
# (S power/NN)
# (S from/IN)
# (S (GPE Iowa/NNP))
# (S wind/NN)
# (S farm/NN)
# (S ''/'')
# (S ./.)
# (S (GPE News/NNP) ./. techworld/NN ./. com/NN)
# (S ./.)
# (S July/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S February/NNP)
# (S 2/CD)
# (S ,/,)
# (S 2012/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S October/NNP)
# (S 26/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Hölzle/NN))
# (S ,/,)
# (S (GPE Urs/NN))
# (S (/()
# (S December/NNP)
# (S 6/CD)
# (S ,/,)
# (S 2016/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S We/PRP)
# (S '/POS re/NN)
# (S set/NN)
# (S to/TO)
# (S reach/NN)
# (S 100/CD)
# (S %/NN)
# (S renewable/JJ)
# (S energy/NN)
# (S —/NN)
# (S and/CC)
# (S it/PRP)
# (S '/POS s/NN)
# (S just/RB)
# (S the/DT)
# (S beginning/VBG)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Keyword/NNP))
# (S (GPE Google/NN))
# (S (GPE Blog/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S December/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S December/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Statt/NN))
# (S ,/,)
# (S (PERSON Nick/NN))
# (S (/()
# (S December/NNP)
# (S 6/CD)
# (S ,/,)
# (S 2016/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S just/RB)
# (S notched/VBN)
# (S a/DT)
# (S big/JJ)
# (S victory/NN)
# (S in/IN)
# (S the/DT)
# (S fight/NN)
# (S against/IN)
# (S climate/NN)
# (S change/NN)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Verge/NN))
# (S ./.)
# (S (GPE Vox/NN))
# (S (GPE Media/NNP))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S December/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S December/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Etherington/NN))
# (S ,/,)
# (S (PERSON Darrell/NNP))
# (S (/()
# (S December/NNP)
# (S 7/CD)
# (S ,/,)
# (S 2016/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S says/VBZ)
# (S it/PRP)
# (S will/MD)
# (S hit/NN)
# (S 100/CD)
# (S %/NN)
# (S renewable/JJ)
# (S energy/NN)
# (S by/IN)
# (S 2017/CD)
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION TechCrunch/NN))
# (S ./.)
# (S (ORGANIZATION AOL/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S December/NNP)
# (S 7/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S December/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S ^/NN)
# (S Donnelly/RB)
# (S ,/,)
# (S (GPE Grace/NN))
# (S (/()
# (S November/NNP)
# (S 30/CD)
# (S ,/,)
# (S 2017/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S Just/RB)
# (S (GPE Bought/NNP))
# (S Enough/RB)
# (S Wind/IN)
# (S (GPE Power/NN))
# (S to/TO)
# (S Run/VB)
# (S 100/CD)
# (S %/NN)
# (S On/IN)
# (S Renewable/JJ)
# (S (GPE Energy/NNP))
# (S ''/'')
# (S ./.)
# (S Fortune/NN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S December/NNP)
# (S 1/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S December/NNP)
# (S 1/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S correspondent/NN)
# (S ,/,)
# (S (GPE Jillian/JJ))
# (S Ambrose/VB)
# (S (GPE Energy/NNP))
# (S (/()
# (S September/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2019/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S signs/NNS)
# (S up/RB)
# (S to/TO)
# (S $/$)
# (S 2bn/CD)
# (S wind/NN)
# (S and/CC)
# (S solar/NN)
# (S investment/NN)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Guardian/JJ))
# (S ./.)
# (S (ORGANIZATION ISSN/NN))
# (S 0261/CD -/: 3077/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S September/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Legum/NN))
# (S ,/,)
# (S (GPE Judd/NN))
# (S ./.)
# (S ``/``)
# (S These/DT)
# (S corporations/NNS)
# (S are/VBP)
# (S quietly/RB)
# (S bankrolling/NN)
# (S (ORGANIZATION Congress/NNP))
# (S '/'')
# (S top/NN)
# (S climate/NN)
# (S denier/NN)
# (S ''/'')
# (S ./.)
# (S popular/JJ ./. info/NN)
# (S ./.)
# (S Retrieved/VBN)
# (S February/NNP)
# (S 7/CD)
# (S ,/,)
# (S 2020/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Kirchgaessner/NNP))
# (S ,/,)
# (S (PERSON Stephanie/NN))
# (S (/()
# (S October/NNP)
# (S 11/CD)
# (S ,/,)
# (S 2019/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S Revealed/VBN)
# (S :/:)
# (S (GPE Google/NN))
# (S made/VBN)
# (S large/JJ)
# (S contributions/NNS)
# (S to/TO)
# (S climate/NN)
# (S change/NN)
# (S deniers/NNS)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Guardian/JJ))
# (S ./.)
# (S (ORGANIZATION ISSN/NN))
# (S 0261/CD -/: 3077/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S February/NNP)
# (S 7/CD)
# (S ,/,)
# (S 2020/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Kirchgaessner/NNP))
# (S ,/,)
# (S (PERSON Stephanie/NN))
# (S (/()
# (S October/NNP)
# (S 11/CD)
# (S ,/,)
# (S 2019/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S The/DT)
# (S obscure/NN)
# (S law/NN)
# (S that/IN)
# (S explains/NNS)
# (S why/WRB)
# (S (GPE Google/NN))
# (S backs/NNS)
# (S climate/NN)
# (S deniers/NNS)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Guardian/JJ))
# (S ./.)
# (S (ORGANIZATION ISSN/NN))
# (S 0261/CD -/: 3077/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S February/NNP)
# (S 7/CD)
# (S ,/,)
# (S 2020/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S About/IN)
# (S the/DT)
# (S Foundation/NN)
# (S ''/'')
# (S ./.)
# (S (GPE Google/NN))
# (S ,/,)
# (S (GPE Inc/NNP) ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S July/NNP)
# (S 14/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S July/NNP)
# (S 16/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Hafner/NN))
# (S ,/,)
# (S (GPE Katie/NNP))
# (S (/()
# (S September/NNP)
# (S 14/CD)
# (S ,/,)
# (S 2006/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GSP Philanthropy/NN))
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S (GPE Way/NN))
# (S :/:)
# (S Not/RB)
# (S the/DT)
# (S Usual/JJ)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE New/NNP))
# (S (GPE York/NNP))
# (S Times/NNS)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S July/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 9/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Helft/NN))
# (S ,/,)
# (S (GPE Miguel/NN))
# (S (/()
# (S February/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2009/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S (GPE Chief/NN))
# (S for/IN)
# (S Charity/NN)
# (S Steps/NNS)
# (S Down/IN)
# (S on/IN)
# (S (GPE Revamp/NN))
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE New/NNP))
# (S (GPE York/NNP))
# (S Times/NNS)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S April/NNP)
# (S 22/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 9/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Project/NN))
# (S 10/CD)
# (S to/TO)
# (S the/DT)
# (S 100th/NNS)
# (S ''/'')
# (S ./.)
# (S (GPE Google/NN))
# (S ,/,)
# (S (GPE Inc/NNP) ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S June/NNP)
# (S 12/CD)
# (S ,/,)
# (S 2009/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S July/NNP)
# (S 16/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S ^/NN)
# (S (PERSON Van/NN))
# (S (GPE Burskirk/NN))
# (S ,/,)
# (S (GPE Elliot/NN))
# (S (/()
# (S June/NNP)
# (S 28/CD)
# (S ,/,)
# (S 2010/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S Struggles/NNS)
# (S to/TO)
# (S Give/VB)
# (S Away/RB)
# (S $/$)
# (S 10/CD)
# (S million/CD)
# (S ''/'')
# (S ./.)
# (S Wired/VBD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S August/NNP)
# (S 31/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S September/NNP)
# (S 26/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Twohill/NN))
# (S ,/,)
# (S (GPE Lorraine/NN))
# (S (/()
# (S September/NNP)
# (S 24/CD)
# (S ,/,)
# (S 2010/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S $/$)
# (S 10/CD)
# (S million/CD)
# (S for/IN)
# (S (GPE Project/NN))
# (S 10/CD ^/CD 100/CD)
# (S winners/NNS)
# (S ''/'')
# (S ./.)
# (S (GPE Google/NN))
# (S ,/,)
# (S (GPE Inc/NNP) ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S September/NNP)
# (S 26/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S September/NNP)
# (S 26/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S ^/NN)
# (S The/DT)
# (S 2007/CD)
# (S Archived/VBN)
# (S November/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2018/CD)
# (S ,/,)
# (S at/IN)
# (S the/DT)
# (S (GPE Wayback/NN))
# (S (GPE Machine/NN))
# (S Julia/NNS)
# (S (PERSON Robinson/NN))
# (S Mathematics/NNS)
# (S (GPE Festivalat/NN))
# (S (GPE Google/NN))
# (S was/VBD)
# (S the/DT)
# (S founding/VBG)
# (S of/IN)
# (S this/DT)
# (S event/NN)
# (S for/IN)
# (S middle/NN)
# (S school/NN)
# (S and/CC)
# (S high/JJ)
# (S school/NN)
# (S students/NNS)
# (S ./.)
# (S video/NN)
# (S ^/NN)
# (S (GPE Duffy/NN))
# (S ,/,)
# (S (GPE Jill/NN))
# (S (/()
# (S January/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2011/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S Mathletes/NNS)
# (S Receive/VB)
# (S €/$ 1M/CD)
# (S (GPE Donation/NN))
# (S from/IN)
# (S (GPE Google/NN))
# (S ''/'')
# (S ./.)
# (S PC/NN)
# (S (GPE Magazine/NN))
# (S ./.)
# (S (GPE Ziff/NN))
# (S (GPE Davis/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S donating/VBG)
# (S 1/CD)
# (S million/CD)
# (S euros/NNS)
# (S to/TO)
# (S (ORGANIZATION IMO/NN))
# (S ''/'')
# (S ./.)
# (S January/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2011/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S July/NNP)
# (S 24/CD)
# (S ,/,)
# (S 2011/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S February/NNP)
# (S 4/CD)
# (S ,/,)
# (S 2011/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S launches/NNS)
# (S '/POS Legalise/NN)
# (S Love/VB)
# (S '/'')
# (S gay/NN)
# (S rights/NNS)
# (S campaign/NN)
# (S ''/'')
# (S ./.)
# (S (GPE PinkNews/NNP) ./. co/NN ./. uk/NN)
# (S ./.)
# (S July/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2012/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S August/NNP)
# (S 19/CD)
# (S ,/,)
# (S 2014/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S September/NNP)
# (S 9/CD)
# (S ,/,)
# (S 2014/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Drucker/NN))
# (S ,/,)
# (S (GPE Jesse/NN))
# (S (/()
# (S October/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2010/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S 2/CD ./. 4/CD)
# (S %/NN)
# (S (GPE Rate/NN))
# (S Shows/NNS)
# (S How/WRB)
# (S $/$)
# (S 60/CD)
# (S (GPE Billion/NN))
# (S Is/NN)
# (S Lost/VBN)
# (S to/TO)
# (S (GPE Tax/NN))
# (S Loopholes/NNS)
# (S ''/'')
# (S ./.)
# (S (GPE Bloomberg/NNP))
# (S (GPE Businessweek/NN))
# (S ./.)
# (S (GPE Bloomberg/NNP))
# (S L/NNP ./. P/NNP ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S September/NNP)
# (S 22/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S January/NNP)
# (S 22/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S (/()
# (S subscription/NN)
# (S required/VBN)
# (S )/))
# (S ^/NN)
# (S ``/``)
# (S The/DT)
# (S (GPE Case/NN))
# (S Against/IN)
# (S (GPE Google/NN))
# (S ''/'')
# (S ./.)
# (S nytimes/NNS ./. com/NN)
# (S ./.)
# (S February/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 19/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S ranked/NNS)
# (S '/POS worst/JJS)
# (S '/'')
# (S on/IN)
# (S privacy/NN)
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION BBC/NN))
# (S News/NNS)
# (S ./.)
# (S June/NNP)
# (S 11/CD)
# (S ,/,)
# (S 2007/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S October/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2012/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S April/NNP)
# (S 30/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Rosen/NN))
# (S ,/,)
# (S (GPE Jeffrey/NNP))
# (S (/()
# (S November/NNP)
# (S 28/CD)
# (S ,/,)
# (S 2008/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S Gatekeepers/NNS)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE New/NNP))
# (S (GPE York/NNP))
# (S Times/NNS)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S February/NNP)
# (S 28/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 9/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S censors/NNS)
# (S itself/PRP)
# (S for/IN)
# (S (GPE China/NNP))
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION BBC/NN))
# (S News/NNS)
# (S ./.)
# (S January/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2006/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S November/NNP)
# (S 19/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S August/NNP)
# (S 4/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S Plans/NNS)
# (S to/TO)
# (S (GPE Launch/NN))
# (S Censored/VBN)
# (S (GPE Search/NN))
# (S (GPE Engine/NN))
# (S in/IN)
# (S (GPE China/NNP))
# (S ,/,)
# (S Leaked/VBN)
# (S Documents/NNS)
# (S (GPE Reveal/NN))
# (S ·/NN)
# (S (GPE Ryan/NN))
# (S (GPE Gallagher/NN))
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S Intercept/IN)
# (S ./.)
# (S August/NNP)
# (S 1/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S August/NNP)
# (S 1/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S August/NNP)
# (S 4/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Disis/NN))
# (S ,/,)
# (S (GPE Jill/NN))
# (S (/()
# (S September/NNP)
# (S 26/CD)
# (S ,/,)
# (S 2018/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S grilled/VBN)
# (S over/IN)
# (S '/POS Project/NN)
# (S (GPE Dragonfly/NN))
# (S '/'')
# (S at/IN)
# (S (ORGANIZATION Senate/NNP))
# (S hearing/NN)
# (S on/IN)
# (S data/NNS)
# (S privacy/NN)
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION CNN/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S September/NNP)
# (S 26/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Gallagher/NN))
# (S ,/,)
# (S (GPE Ryan/NN))
# (S (/()
# (S December/NNP)
# (S 17/CD)
# (S ,/,)
# (S 2018/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S Secret/JJ)
# (S (GPE China/NNP))
# (S (GPE Project/NN))
# (S ``/``)
# (S Effectively/RB)
# (S Ended/VBD)
# (S ''/'')
# (S After/IN)
# (S Internal/NNP)
# (S Confrontation/NN)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S Intercept/IN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S December/NNP)
# (S 17/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (PERSON Edward/NNP))
# (S (GPE Snowden/NN))
# (S :/:)
# (S Leaks/NNS)
# (S that/IN)
# (S exposed/VBN)
# (S (GSP US/NN))
# (S spy/NN)
# (S programme/NN)
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION BBC/NN))
# (S News/NNS)
# (S ./.)
# (S January/NNP)
# (S 17/CD)
# (S ,/,)
# (S 2014/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Greenwald/NNP))
# (S ,/,)
# (S (PERSON Glenn/NNP))
# (S ;/:)
# (S (ORGANIZATION MacAskill/NN))
# (S ,/,)
# (S (GPE Ewen/NN))
# (S (/()
# (S June/NNP)
# (S 7/CD)
# (S ,/,)
# (S 2013/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (ORGANIZATION NSA/NN))
# (S (GPE Prism/NN))
# (S program/NN)
# (S taps/NNS)
# (S in/IN)
# (S to/TO)
# (S user/NN)
# (S data/NNS)
# (S of/IN)
# (S (GPE Apple/NNP))
# (S ,/,)
# (S (GPE Google/NN))
# (S and/CC)
# (S others/NNS)
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Guardian/JJ))
# (S ./.)
# (S (GPE Guardian/JJ))
# (S (GPE Media/NNP))
# (S (GPE Group/NNP))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S August/NNP)
# (S 18/CD)
# (S ,/,)
# (S 2006/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S employees/NNS)
# (S revolt/NN)
# (S ,/,)
# (S say/VB)
# (S company/NN)
# (S should/MD)
# (S shut/NN)
# (S down/RB)
# (S military/JJ)
# (S drone/NN)
# (S project/NN)
# (S Archived/VBN)
# (S April/NNP)
# (S 8/CD)
# (S ,/,)
# (S 2018/CD)
# (S ,/,)
# (S at/IN)
# (S the/DT)
# (S (GPE Wayback/NN))
# (S (GPE Machine/NN))
# (S ''/'')
# (S ./.)
# (S (GPE Ars/NN))
# (S (GPE Technica/NN))
# (S ./.)
# (S April/NNP)
# (S 4/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S staff/NN)
# (S protest/NN)
# (S company/NN)
# (S '/POS s/NN)
# (S involvement/NN)
# (S with/IN)
# (S (GPE Pentagon/NNP))
# (S drones/NNS)
# (S programme/NN)
# (S Archived/VBN)
# (S April/NNP)
# (S 9/CD)
# (S ,/,)
# (S 2018/CD)
# (S ,/,)
# (S at/IN)
# (S the/DT)
# (S (GPE Wayback/NN))
# (S (GPE Machine/NN))
# (S ''/'')
# (S ./.)
# (S The/DT)
# (S (GPE Independent/NN))
# (S ./.)
# (S April/NNP)
# (S 4/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Wakabayashi/NNP))
# (S ,/,)
# (S (GPE Daisuke/NN))
# (S ;/:)
# (S (GPE Shane/NN))
# (S ,/,)
# (S (GPE Scott/NN))
# (S (/()
# (S June/NNP)
# (S 1/CD)
# (S ,/,)
# (S 2018/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S Will/MD)
# (S Not/RB)
# (S (GPE Renew/NN))
# (S (GPE Pentagon/NNP))
# (S (GSP Contract/NN))
# (S That/DT)
# (S Upset/VBN)
# (S Employees/NNS)
# (S ''/'')
# (S ./.)
# (S nytimes/NNS ./. com/NN)
# (S ./.)
# (S The/DT)
# (S (GPE New/NNP))
# (S (GPE York/NNP))
# (S Times/NNS)
# (S (GPE Company/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S October/NNP)
# (S 16/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S October/NNP)
# (S 16/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S Thousands/NNS)
# (S of/IN)
# (S (GPE Reddit/NN))
# (S users/NNS)
# (S are/VBP)
# (S trying/VBG)
# (S to/TO)
# (S delete/NN)
# (S (GPE Google/NN))
# (S from/IN)
# (S their/PRP$)
# (S lives/NNS)
# (S ,/,)
# (S but/CC)
# (S they/PRP)
# (S '/POS re/NN)
# (S finding/VBG)
# (S it/PRP)
# (S impossible/JJ)
# (S because/IN)
# (S (GPE Google/NN))
# (S is/VBZ)
# (S everywhere/RB)
# (S ''/'')
# (S ./.)
# (S March/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S April/NNP)
# (S 24/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S Kan/NNP)
# (S ,/,)
# (S By/IN)
# (S (GPE Michael/NNP))
# (S ;/:)
# (S July/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2018/CD)
# (S 12/CD :/: 39PM/CD)
# (S (ORGANIZATION EST/NN))
# (S ;/:)
# (S July/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ``/``)
# (S (GPE Mozilla/NN))
# (S (GPE Developer/NN))
# (S Claims/NNS)
# (S (GPE Google/NN))
# (S Is/NN)
# (S Slowing/VBG)
# (S (ORGANIZATION YouTube/NN))
# (S on/IN)
# (S (GPE Firefox/NN))
# (S ''/'')
# (S ./.)
# (S (GPE PCMAG/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S August/NNP)
# (S 13/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S August/NNP)
# (S 13/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Cimpanu/NN))
# (S ,/,)
# (S (GPE Catalin/NN))
# (S ./.)
# (S ``/``)
# (S Former/NN)
# (S (GPE Mozilla/NN))
# (S exec/NN)
# (S :/:)
# (S (GPE Google/NN))
# (S has/VBZ)
# (S sabotaged/VBN)
# (S (GPE Firefox/NN))
# (S for/IN)
# (S years/NNS)
# (S ''/'')
# (S ./.)
# (S ZDNet/NN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S August/NNP)
# (S 19/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S August/NNP)
# (S 13/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Copeland/NN))
# (S ,/,)
# (S (PERSON Rob/NN))
# (S (/()
# (S November/NNP)
# (S 12/CD)
# (S ,/,)
# (S 2019/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S '/POS Project/NN)
# (S (GPE Nightingale/NN))
# (S '/'')
# (S Triggers/NNS)
# (S Federal/JJ)
# (S (GPE Inquiry/NN))
# (S ''/'')
# (S ./.)
# (S Retrieved/VBN)
# (S November/NNP)
# (S 18/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Copeland/NN))
# (S ,/,)
# (S (PERSON Rob/NN))
# (S (/()
# (S November/NNP)
# (S 11/CD)
# (S ,/,)
# (S 2019/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S '/POS Project/NN)
# (S (GPE Nightingale/NN))
# (S '/'')
# (S Gathers/NNS)
# (S Personal/JJ)
# (S (GPE Health/NNP))
# (S Data/NNS)
# (S on/IN)
# (S Millions/NNS)
# (S of/IN)
# (S Americans/NNS)
# (S ''/'')
# (S ./.)
# (S Retrieved/VBN)
# (S November/NNP)
# (S 17/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Rosenblatt/NN))
# (S ,/,)
# (S (GPE Joel/NN))
# (S (/()
# (S March/NNP)
# (S 2/CD)
# (S ,/,)
# (S 2015/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Apple/NNP) -/: (GPE Google/NN))
# (S $/$)
# (S 415/CD)
# (S (PERSON Million/NN))
# (S No/DT -/: Poaching/NN)
# (S (GPE Accord/NN))
# (S Wins/NNS)
# (S (GPE Approval/NN))
# (S ''/'')
# (S ./.)
# (S (GPE Bloomberg/NNP))
# (S L/NNP ./. P/NNP ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S January/NNP)
# (S 30/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S January/NNP)
# (S 24/CD)
# (S ,/,)
# (S 2016/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Kelion/NN))
# (S ,/,)
# (S (GPE Leo/NN))
# (S (/()
# (S June/NNP)
# (S 27/CD)
# (S ,/,)
# (S 2017/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S hit/NN)
# (S with/IN)
# (S record/NN)
# (S (GPE EU/NN))
# (S fine/NN)
# (S over/IN)
# (S Shopping/VBG)
# (S service/NN)
# (S ''/'')
# (S ./.)
# (S bbc/NN ./. co/NN ./. uk/NN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S June/NNP)
# (S 27/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S June/NNP)
# (S 29/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S €/RB 2/CD ./. 4bn/CD)
# (S fine/NN)
# (S is/VBZ)
# (S small/JJ)
# (S change/NN)
# (S –/NN)
# (S the/DT)
# (S (GPE EU/NN))
# (S has/VBZ)
# (S bigger/JJR)
# (S plans/NNS)
# (S ''/'')
# (S ./.)
# (S newscientist/NN ./. com/NN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S January/NNP)
# (S 24/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S June/NNP)
# (S 29/CD)
# (S ,/,)
# (S 2017/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S starts/NNS)
# (S appeal/NN)
# (S against/IN)
# (S £/$ 2bn/CD)
# (S shopping/NN)
# (S fine/NN)
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION BBC/NN))
# (S News/NNS)
# (S ./.)
# (S February/NNP)
# (S 12/CD)
# (S ,/,)
# (S 2020/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S Antitrust/JJ)
# (S :/:)
# (S Commission/NNP)
# (S fines/NNS)
# (S (GPE Google/NN))
# (S €/RB 4/CD ./. 34/CD)
# (S billion/CD)
# (S for/IN)
# (S illegal/JJ)
# (S practices/NNS)
# (S regarding/VBG)
# (S (GPE Android/NN))
# (S mobile/NN)
# (S devices/NNS)
# (S to/TO)
# (S strengthen/NN)
# (S dominance/NN)
# (S of/IN)
# (S (GPE Google/NN))
# (S '/POS s/NN)
# (S search/NN)
# (S engine/NN)
# (S ''/'')
# (S ./.)
# (S (GPE European/JJ))
# (S Commission/NNP)
# (S ./.)
# (S Bruxelles/NNS)
# (S ./.)
# (S July/NNP)
# (S 18/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S July/NNP)
# (S 18/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Google/NN))
# (S appeals/NNS)
# (S $/$)
# (S 5/CD)
# (S billion/CD)
# (S (GPE EU/NN))
# (S fine/NN)
# (S in/IN)
# (S (GPE Android/NN))
# (S antitrust/JJ)
# (S case/NN)
# (S ''/'')
# (S ./.)
# (S (GPE APNews/NNP) ./. com/NN)
# (S ./.)
# (S Bruxelles/NNS)
# (S ./.)
# (S October/NNP)
# (S 10/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S October/NNP)
# (S 10/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Foo/NN))
# (S (GPE Yun/NN))
# (S (GPE Chee/NN))
# (S (/()
# (S May/NNP)
# (S 13/CD)
# (S ,/,)
# (S 2014/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S challenges/NNS)
# (S record/NN)
# (S $/$)
# (S 5/CD)
# (S billion/CD)
# (S (GPE EU/NN))
# (S antitrust/JJ)
# (S fine/NN)
# (S ''/'')
# (S ./.)
# (S Reuters/NNS)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S December/NNP)
# (S 22/CD)
# (S ,/,)
# (S 2018/CD)
# (S ./.)
# (S ^/NN)
# (S (PERSON Fox/NN))
# (S ,/,)
# (S (GPE Chris/NN))
# (S (/()
# (S January/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2019/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S (GPE Google/NN))
# (S hit/NN)
# (S with/IN)
# (S £/$ 44m/CD)
# (S (ORGANIZATION GDPR/NN))
# (S fine/NN)
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION BBC/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S January/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S January/NNP)
# (S 22/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Europe/NNP))
# (S hits/NNS)
# (S (GPE Google/NN))
# (S with/IN)
# (S a/DT)
# (S third/JJ)
# (S ,/,)
# (S $/$)
# (S 1/CD ./. 7/CD)
# (S billion/CD)
# (S antitrust/JJ)
# (S fine/NN)
# (S ''/'')
# (S ./.)
# (S (ORGANIZATION CNN/NN))
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 21/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S (GPE Reid/NN))
# (S ,/,)
# (S (PERSON David/NNP))
# (S ./.)
# (S ``/``)
# (S (GPE EU/NN))
# (S regulators/NNS)
# (S hit/NN)
# (S (GPE Google/NN))
# (S with/IN)
# (S $/$)
# (S 1/CD ./. 7/CD)
# (S billion/CD)
# (S fine/NN)
# (S for/IN)
# (S blocking/VBG)
# (S ad/NN)
# (S rivals/NNS)
# (S ''/'')
# (S ./.)
# (S CNBC/NNP ./. com/NN)
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S March/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S March/NNP)
# (S 20/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S (GPE Tulsi/NN))
# (S (PERSON Gabbard/NNP))
# (S sues/NNS)
# (S (GPE Google/NN))
# (S over/IN)
# (S censorship/NN)
# (S claims/NNS)
# (S ''/'')
# (S ./.)
# (S July/NNP)
# (S 25/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S Thousands/NNS)
# (S of/IN)
# (S (GPE Reddit/NN))
# (S users/NNS)
# (S are/VBP)
# (S trying/VBG)
# (S to/TO)
# (S delete/NN)
# (S (GPE Google/NN))
# (S from/IN)
# (S their/PRP$)
# (S lives/NNS)
# (S ,/,)
# (S but/CC)
# (S they/PRP)
# (S '/POS re/NN)
# (S finding/VBG)
# (S it/PRP)
# (S impossible/JJ)
# (S because/IN)
# (S (GPE Google/NN))
# (S is/VBZ)
# (S everywhere/RB)
# (S ''/'')
# (S ./.)
# (S March/NNP)
# (S 23/CD)
# (S ,/,)
# (S 2019/CD)
# (S ./.)
# (S ^/NN)
# (S ``/``)
# (S I/PRP)
# (S (GPE Cut/NN))
# (S (GPE Google/NN))
# (S Out/IN)
# (S Of/IN)
# (S My/PRP$)
# (S (GPE Life/NN))
# (S ./.)
# (S It/PRP)
# (S Screwed/VBN)
# (S Up/IN)
# (S Everything/NN)
# (S ''/'')
# (S ./.)
# (S Further/RB)
# (S reading/NN)
# (S (GPE Saylor/NN))
# (S ,/,)
# (S (GPE Michael/NNP))
# (S (/()
# (S 2012/CD)
# (S )/))
# (S ./.)
# (S The/DT)
# (S (GPE Mobile/NN))
# (S Wave/VB)
# (S :/:)
# (S How/WRB)
# (S (GPE Mobile/NN))
# (S (GPE Intelligence/NN))
# (S Will/MD)
# (S (GPE Change/NN))
# (S Everything/NN)
# (S ./.)
# (S (GPE Perseus/NN))
# (S (PERSON Books/NNP) //NNP Vanguard/NNP)
# (S Press/NN)
# (S ./.)
# (S (ORGANIZATION ISBN/NN))
# (S 978/CD -/: 1593157203/CD)
# (S ./.)
# (S External/JJ)
# (S links/NNS)
# (S (GPE Googleat/NN))
# (S (GPE Wikipedia/NNP))
# (S '/POS s/NN)
# (S sister/NN)
# (S projectsDefinitions/NNS)
# (S from/IN)
# (S Wiktionary/JJ)
# (S (GPE Media/NNP))
# (S from/IN)
# (S (GPE Wikimedia/NNP))
# (S Commons/NNS)
# (S News/NNS)
# (S from/IN)
# (S Wikinews/NNS)
# (S Quotations/NNS)
# (S from/IN)
# (S (GPE Wikiquote/NN))
# (S Textbooks/NNS)
# (S from/IN)
# (S Wikibooks/NNS)
# (S Resources/NNS)
# (S from/IN)
# (S (GPE Wikiversity/NN))
# (S Data/NNS)
# (S from/IN)
# (S Wikidata/NNS)
# (S (GPE Discussion/NN))
# (S from/IN)
# (S (GPE Meta/NNP) -/: (PERSON Wiki/NN))
# (S Official/NN)
# (S website/NN)
# (S Corporate/JJ)
# (S homepage/NN)
# (S ''/'')
# (S (GPE Google/NN))
# (S website/NN)
# (S ''/'')
# (S ./.)
# (S Archived/VBN)
# (S from/IN)
# (S the/DT)
# (S original/JJ)
# (S on/IN)
# (S November/NNP)
# (S 11/CD)
# (S ,/,)
# (S 1998/CD)
# (S ./.)
# (S Retrieved/VBN)
# (S September/NNP)
# (S 28/CD)
# (S ,/,)
# (S 2010/CD)
# (S ./.)
# (S (PERSON Carr/NN))
# (S ,/,)
# (S (PERSON David/NNP))
# (S F/NNP ./.)
# (S (/()
# (S 2006/CD)
# (S )/))
# (S ./.)
# (S ``/``)
# (S How/WRB)
# (S (GPE Google/NN))
# (S Works/NNS)
# (S ''/'')
# (S ./.)
# (S (GPE Baseline/NN))
# (S (GPE Magazine/NN))
# (S ./.)
# (S 6/CD)
# (S (/()
# (S 6/CD)
# (S )/))
# (S ./.)
# (S (GPE Google/NN))
# (S at/IN)
# (S (GPE Crunchbase/NN))
# (S (GPE Google/NN))
# (S companies/NNS)
# (S grouped/NNS)
# (S at/IN)
# (S OpenCorporates/NNS)
# (S (GPE Business/NN))
# (S data/NNS)
# (S for/IN)
# (S (GPE Google/NN))
# (S ,/,)
# (S (GPE Inc/NNP) ./.)
# (S :/:)
# (S SEC/NNP)
# (S filings/NNS)
# (S (ORGANIZATION vteGoogle/NN))
# (S (GPE Alphabet/NN))
# (S (GPE Inc/NNP) ./.)
# (S (GPE Ads/NN))
# (S (GPE Android/NN))
# (S Devices/NNS)
# (S (GPE Nexus/NN))
# (S (GPE Pixel/NN))
# (S Maps/NNS)
# (S (ORGANIZATION YouTube/NN))
# (S (GPE Company/NN))
# (S (GPE Overview/NN))
# (S (GPE Alphabet/NN))
# (S (GPE Inc/NNP) ./.)
# (S (GPE History/NN))
# (S (GPE List/NN))
# (S of/IN)
# (S mergers/NNS)
# (S and/CC)
# (S acquisitions/NNS)
# (S by/IN)
# (S (GPE Alphabet/NN))
# (S (GPE List/NN))
# (S of/IN)
# (S products/NNS)
# (S Criticism/NN)
# (S (GPE Privacy/NN))
# (S concerns/NNS)
# (S (GPE Censorship/NN))
# (S Litigation/NN)
# (S Do/VB)
# (S n/NN '/'' t/NN)
# (S be/VB)
# (S evil/NN)
# (S (GPE Worker/NN))
# (S organization/NN)
# (S (GPE Real/JJ))
# (S estates/NNS)
# (S 111/CD)
# (S Eighth/NNS)
# (S (GPE Avenue/NN))
# (S (GPE Chelsea/NN))
# (S (GPE Market/NN))
# (S (GPE Googleplex/NNP))
# (S Data/NNS)
# (S centers/NNS)
# (S Divisions/NNS)
# (S (GPE Android/NN))
# (S (GPE Glass/NN))
# (S (GPE Google/NN))
# (S (GPE Ads/NN))
# (S (GPE Google/NN))
# (S AI/NN)
# (S (GPE Google/NN))
# (S (GPE Chrome/NN))
# (S (GPE Google/NN))
# (S (GPE Cloud/NN))
# (S (GPE Google/NN))
# (S Maps/NNS)
# (S (GPE Google/NN))
# (S Nest/JJS)
# (S (GPE Google/NN))
# (S (GPE Pixel/NN))
# (S (GPE Google/NN))
# (S (GPE Search/NN))
# (S (ORGANIZATION YouTube/NN))
# (S Events/NNS)
# (S (GPE Code/NNP) -/: in/IN)
# (S (GPE Code/NN))
# (S (GPE Jam/NN))
# (S (GPE Developer/NN))
# (S Day/NNP)
# (S I/PRP //VBP O/JJ)
# (S (GPE Science/NN))
# (S (GPE Fair/NN))
# (S (GPE Summer/NN))
# (S of/IN)
# (S (GPE Code/NN))
# (S Talks/NNS)
# (S at/IN)
# (S (GPE Google/NN))
# (S People/NNS)
# (S (GPE Al/NN))
# (S (GPE Gore/NN))
# (S (GPE Alan/NNP))
# (S (GPE Eustace/NN))
# (S (GPE Alan/NNP))
# (S Mulally/RB)
# (S (GPE Amit/NN))
# (S (GPE Singhal/NN))
# (S (PERSON Ann/NN))
# (S (GPE Mather/NN))
# (S (PERSON David/NNP))
# (S (GPE Drummond/NN))
# (S (GPE Eric/JJ))
# (S (GPE Schmidt/NN))
# (S (GPE Jeff/NN))
# (S (GPE Dean/NN))
# (S (PERSON John/NNP))
# (S (GPE Doerr/NN))
# (S (PERSON John/NNP))
# (S L/NNP ./.)
# (S (GPE Hennessy/NN))
# (S (GPE Krishna/NNP))
# (S (GPE Bharat/NNP))
# (S (GPE Matt/NN))
# (S (GPE Cutts/NN))
# (S (PERSON Patrick/NNP))
# (S (GPE Pichette/NN))
# (S (PERSON Paul/NNP))
# (S (GPE Otellini/NN))
# (S (GPE Omid/NN))
# (S (GPE Kordestani/NNP))
# (S (GPE Rachel/NN))
# (S Whetstone/NN)
# (S (GPE Rajen/NN))
# (S (GPE Sheth/NN))
# (S (GPE Ram/NN))
# (S (GPE Shriram/NN))
# (S (GPE Ray/NN))
# (S (GPE Kurzweil/NNP))
# (S (GPE Ruth/NN))
# (S (GPE Porat/NN))
# (S (GPE Salar/JJ))
# (S (GPE Kamangar/NNP))
# (S (GPE Sanjay/NN))
# (S (GPE Ghemawat/NN))
# (S (GPE Shirley/NN))
# (S M/NNP ./.)
# (S (GPE Tilghman/NN))
# (S (GPE Sundar/NN))
# (S (GPE Pichai/NN))
# (S (GPE Susan/NNP))
# (S (GPE Wojcicki/NN))
# (S (GPE Urs/NN))
# (S (GPE Hölzle/NN))
# (S (GPE Vint/NN))
# (S (GPE Cerf/NN))
# (S (GPE Hal/NN))
# (S (GPE Varian/JJ))
# (S Terms/NNS)
# (S Gayglers/NNS)
# (S (GPE Google/NN))
# (S (GPE Developer/NN))
# (S (GPE Expert/NN))
# (S Founders/NNS)
# (S (PERSON Larry/NNP))
# (S Page/NN)
# (S (GPE Sergey/NN))
# (S (GPE Brin/NN))
# (S ProductsSoftware/NN)
# (S (GPE Assistant/NN))
# (S (GPE Camera/NN))
# (S Lens/NNS)
# (S (GPE Chrome/NN))
# (S for/IN)
# (S (GPE Android/NN))
# (S Web/NN)
# (S (GPE Store/NN))
# (S (GPE Chromium/NN))
# (S (GPE Cloud/NN))
# (S (GPE Print/NN))
# (S (GPE Earth/NN))
# (S Gadgets/NNS)
# (S (PERSON Gboard/NNP))
# (S IME/NN)
# (S (GPE Japanese/JJ))
# (S (GPE Pinyin/NN))
# (S (GPE Pay/NN))
# (S Photos/NNS)
# (S Keep/VB)
# (S News/NNS)
# (S Now/RB)
# (S (ORGANIZATION OpenRefine/NN))
# (S (GPE Snapseed/NN))
# (S Operating/NN)
# (S systems/NNS)
# (S (GPE Android/NN))
# (S version/NN)
# (S history/NN)
# (S software/NN)
# (S development/NN)
# (S (GPE Android/NN))
# (S Automotive/JJ)
# (S (GPE Android/NN))
# (S TV/NN)
# (S Wear/IN)
# (S OS/NN)
# (S (GPE List/NN))
# (S of/IN)
# (S devices/NNS)
# (S (GPE Chrome/NN))
# (S OS/NN)
# (S (GPE Apps/NN))
# (S (GPE Fuchsia/NN))
# (S Programming/VBG)
# (S languages/NNS)
# (S (GPE Dart/NN))
# (S Go/VB)
# (S (GPE Sawzall/NN))
# (S Frameworks/NNS)
# (S Angular/JJ)
# (S (ORGANIZATION AngularJS/NN))
# (S (ORGANIZATION AJAX/NN))
# (S (ORGANIZATION APIs/NN))
# (S (GPE Dialogflow/NN))
# (S Flutter/NN)
# (S (GPE Guava/NN))
# (S Guice/NN)
# (S (ORGANIZATION TensorFlow/NN))
# (S Communication/NN)
# (S Alerts/NNS)
# (S (GPE Apps/NN))
# (S (GPE Script/NN))
# (S (GPE Duo/NN))
# (S (GPE Calendar/NN))
# (S Contacts/NNS)
# (S (GPE Gmail/NN))
# (S history/NN)
# (S interface/NN)
# (S Groups/NNS)
# (S Hangouts/NNS)
# (S (GPE Sync/NN))
# (S (GPE Text/NNP) -/: to/TO -/: (GPE Speech/NN))
# (S (GPE Translate/NN))
# (S (GPE Transliteration/NN))
# (S Voice/NN)
# (S Platforms/NNS)
# (S (GPE Account/NN))
# (S Authenticator/NN)
# (S (GPE Android/NN))
# (S (GPE Auto/NN))
# (S (ORGANIZATION ZygoteBody/NN))
# (S (GPE Cast/NN))
# (S (GPE Cloud/NN))
# (S (ORGANIZATION AppSheet/NN))
# (S (GPE Fit/NN))
# (S (ORGANIZATION GFS/NN))
# (S G/NN)
# (S (GPE Suite/NN))
# (S (GPE Native/NN))
# (S (PERSON Client/NN))
# (S OpenSocial/JJ)
# (S (GPE Pay/NN))
# (S (GPE Primer/NN))
# (S Play/VB)
# (S Books/NNS)
# (S Games/NNS)
# (S Movies/NNS)
# (S &/CC)
# (S TV/NN)
# (S (GPE Music/JJ))
# (S (GPE Public/JJ))
# (S (ORGANIZATION DNS/NN))
# (S Safe/JJ)
# (S Browsing/VBG)
# (S (GPE Stadia/NNP))
# (S (GPE Tango/NN))
# (S (GPE Google/NN))
# (S Web/NN)
# (S (GPE Server/NN))
# (S (ORGANIZATION YouTube/NN))
# (S Development/NNP)
# (S (GPE App/NN))
# (S Inventor/NN)
# (S (GPE Caja/NN))
# (S (GPE Closure/NN))
# (S Tools/NNS)
# (S Developers/NNS)
# (S (GPE Firebase/NN))
# (S GData/NNS)
# (S KML/NNP)
# (S (GPE Kythe/NNP))
# (S (ORGANIZATION MapReduce/NN))
# (S (GPE Owlchemy/NN))
# (S Labs/NNS)
# (S Web/NN)
# (S (GPE Toolkit/NN))
# (S (GPE Search/NN))
# (S (GSP Console/NN))
# (S (GPE Website/NNP))
# (S (GPE Optimizer/NN))
# (S (GPE Swiffy/NN))
# (S Publishing/VBG)
# (S (ORGANIZATION AMP/NN))
# (S (GPE Blogger/NN))
# (S Bookmarks/NNS)
# (S Domains/NNS)
# (S (GPE Drive/NN))
# (S (GPE Docs/NN))
# (S Sheets/NNS)
# (S Slides/NNS)
# (S Drawings/NNS)
# (S Forms/NNS)
# (S (ORGANIZATION FeedBurner/NN))
# (S Podcasts/NNS)
# (S Sites/NNS)
# (S (ORGANIZATION YouTube/NN))
# (S Instant/NN)
# (S Premium/NN)
# (S (GPE Vevo/NN))
# (S (GPE Zagat/NN))
# (S (GPE Search/NN))
# (S (/()
# (S timeline/NN)
# (S )/))
# (S (GPE Blog/NN))
# (S (GPE Search/NN))
# (S Books/NNS)
# (S (GPE Ngram/NN))
# (S (GSP Viewer/NN))
# (S (GPE Custom/NN))
# (S (GPE Search/NN))
# (S (GPE Dataset/NN))
# (S (GPE Search/NN))
# (S Dictionary/JJ)
# (S (GPE Finance/NN))
# (S Flights/NNS)
# (S (GPE Googlebot/NNP))
# (S Images/NNS)
# (S Maps/NNS)
# (S (GPE Street/NNP))
# (S (GSP View/NN))
# (S (GPE Coverage/NN))
# (S (GPE Privacy/NN))
# (S concerns/NNS)
# (S News/NNS)
# (S Archive/JJ)
# (S Patents/NNS)
# (S (GPE Public/JJ))
# (S Data/NNS)
# (S (GPE Scholar/NN))
# (S Shopping/VBG)
# (S (GPE Tenor/NN))
# (S Videos/NNS)
# (S (GPE Algorithms/NN))
# (S (ORGANIZATION PageRank/NN))
# (S (GSP Panda/NN))
# (S (GPE Penguin/NN))
# (S (GPE Hummingbird/NN))
# (S Features/NNS)
# (S Personalized/VBN)
# (S SafeSearch/NN)
# (S Voice/NN)
# (S (GPE Search/NN))
# (S (GPE Analysis/NN))
# (S Insights/NNS)
# (S for/IN)
# (S (GPE Search/NN))
# (S Trends/NNS)
# (S Knowledge/NN)
# (S (GPE Graph/NN))
# (S and/CC)
# (S (GPE Vault/NN))
# (S (GPE Hardware/NN))
# (S (GPE Glass/NN))
# (S (GPE Home/NN))
# (S (PERSON Jamboard/NN))
# (S (GPE OnHub/NN))
# (S (GPE Virtual/JJ))
# (S reality/NN)
# (S (PERSON Cardboard/NN))
# (S (GPE Daydream/NN))
# (S Nest/JJS)
# (S Nest/JJS)
# (S Learning/VBG)
# (S Thermostat/NN)
# (S Nest/JJS)
# (S (GPE Wifi/NN))
# (S Smartphones/NNS)
# (S (GPE Nexus/NN))
# (S (GPE Pixel/NN))
# (S (GPE Chrome/NN))
# (S (GPE Chromebit/NN))
# (S (GPE Chromecast/NN))
# (S (GPE Chromebook/NN))
# (S (GPE Chromebox/NN))
# (S Other/JJ)
# (S ./. google/NN)
# (S Arts/NNS)
# (S &/CC)
# (S (GPE Culture/NN))
# (S (ORGANIZATION ATAP/NN))
# (S (GPE Chrome/NN))
# (S (GPE Zone/NN))
# (S Data/NNS)
# (S (GPE Transfer/NN))
# (S (GPE Project/NN))
# (S (GPE Dragonfly/NN))
# (S (GPE Current/NN))
# (S (GPE Chrome/NN))
# (S Experiments/NNS)
# (S (GPE Google/NN))
# (S (GPE Business/NN))
# (S Groups/NNS)
# (S Made/VBN)
# (S with/IN)
# (S (GPE Code/NN))
# (S Data/NNS)
# (S (GPE Liberation/NN))
# (S (GPE Takeout/NN))
# (S (GPE Google/NN))
# (S (/()
# (S verb/NN)
# (S )/))
# (S (GPE Google/NN))
# (S (GPE China/NNP))
# (S (GPE Google/NN))
# (S (GPE Express/NN))
# (S Googlization/NN)
# (S (GPE Google/NNP) ./. org/NN)
# (S (GPE Logo/NN))
# (S and/CC)
# (S related/JJ)
# (S (GPE Doodle4Google/NN))
# (S (GPE Google/NN))
# (S Doodles/NNS)
# (S (GPE Lunar/NN))
# (S X/NN)
# (S Prize/VB)
# (S (GPE Google/NN))
# (S (GPE Fi/NN))
# (S (GPE Google/NN))
# (S Station/NN)
# (S (GPE Material/NN))
# (S Design/NN)
# (S (GPE Motorola/NNP))
# (S (GPE Mobility/NN))
# (S Nest/JJS)
# (S Labs/NNS)
# (S (ORGANIZATION reCAPTCHA/NN))
# (S (GPE Sunroof/NN))
# (S (ORGANIZATION WiFi/NN))
# (S AI/NN)
# (S Challenge/NN)
# (S (GPE Easter/NN))
# (S eggs/NNS)
# (S (GPE elgooG/NN))
# (S (GPE Related/JJ))
# (S (GPE Google/NN))
# (S bombing/NN)
# (S (GPE Goojje/NN))
# (S (GPE Monopoly/NN))
# (S (GPE City/NNP))
# (S Streets/NNS)
# (S (GPE Unity/NN))
# (S Documentaries/NNS)
# (S (GPE Google/NN))
# (S :/:)
# (S Behind/IN)
# (S the/DT)
# (S (GPE Screen/NN))
# (S (GPE Google/NN))
# (S :/:)
# (S The/DT)
# (S Thinking/VBG)
# (S (GPE Factory/NN))
# (S (GPE Google/NN))
# (S and/CC)
# (S the/DT)
# (S World/NN)
# (S (GPE Brain/NN))
# (S (GPE Category/NN))
# (S Companies/NNS)
# (S portal/NN)
# (S Internet/NN)
# (S portal/NN)
# (S Discontinued/VBN)
# (S products/NNS)
# (S and/CC)
# (S services/NNS)
# (S (ORGANIZATION vteAlphabet/NN))
# (S (GPE Inc/NNP) ./. Subsidiaries/NNS)
# (S (GPE Access/NN))
# (S (GPE Google/NN))
# (S Fiber/NNP)
# (S (GPE Calico/NN))
# (S CapitalG/NN)
# (S (ORGANIZATION DeepMind/NN))
# (S (GPE Google/NN))
# (S GV/NN)
# (S (GPE Jigsaw/NN))
# (S (GPE Loon/NN))
# (S (GPE Makani/NN))
# (S (GPE Sidewalk/NN))
# (S Labs/NNS)
# (S Verily/RB)
# (S X/NN)
# (S (GPE Waymo/NN))
# (S Wing/VBG)
# (S People/NNS)
# (S (PERSON Andrew/NN))
# (S (GSP Conrad/NN))
# (S (GPE Tony/NN))
# (S (GPE Fadell/NN))
# (S (GPE Arthur/NNP))
# (S (GPE D/NNP) ./.)
# (S (GPE Levinson/NN))
# (S (PERSON David/NNP))
# (S (GPE Krane/NNP))
# (S (GPE Ruth/NN))
# (S (GPE Porat/NN))
# (S (GPE Astro/NNP))
# (S (GPE Teller/NN))
# (S Executives/NNS)
# (S (GPE Sundar/NN))
# (S (GPE Pichai/NN))
# (S (/()
# (S CEO/NN)
# (S )/))
# (S (GPE Ruth/NN))
# (S (GPE Porat/NN))
# (S (/()
# (S (ORGANIZATION CFO/NN))
# (S )/))
# (S (PERSON David/NNP))
# (S (GPE Drummond/NN))
# (S (/()
# (S (ORGANIZATION CLO/NN))
# (S )/))
# (S (PERSON Board/NNP))
# (S of/IN)
# (S directorsCurrent/NN)
# (S (GPE Sergey/NN))
# (S (GPE Brin/NN))
# (S (PERSON John/NNP))
# (S (GPE Doerr/NN))
# (S (PERSON John/NNP))
# (S L/NNP ./.)
# (S (GPE Hennessy/NN))
# (S (PERSON Ann/NN))
# (S (GPE Mather/NN))
# (S (GPE Alan/NNP))
# (S Mulally/RB)
# (S (PERSON Larry/NNP))
# (S Page/NN)
# (S (GPE Sundar/NN))
# (S (GPE Pichai/NN))
# (S (GPE Ram/NN))
# (S (GPE Shriram/NN))
# (S (PERSON Roger/NN))
# (S W/NNP ./.)
# (S (GPE Ferguson/NN))
# (S (GPE Jr/NNP) ./.)
# (S Former/NN)
# (S (GPE Eric/JJ))
# (S (GPE Schmidt/NN))
# (S (GPE Diane/NN))
# (S (GPE Greene/NNP))
# (S Founders/NNS)
# (S (PERSON Larry/NNP))
# (S Page/NN)
# (S (GPE Sergey/NN))
# (S (GPE Brin/NN))
# (S (GPE Category/NN))
# (S Companies/NNS)
# (S portal/NN)
# (S Internet/NN)
# (S portal/NN)
# (S Links/NNS)
# (S to/TO)
# (S related/JJ)
# (S articles/NNS)
# (S (ORGANIZATION vteOpen/NN))
# (S (GPE Handset/NN))
# (S AllianceMobile/NN)
# (S operators/NNS)
# (S Bouygues/NNS)
# (S (GPE Telecom/NN))
# (S (GPE China/NNP))
# (S (GPE Mobile/NN))
# (S (GPE China/NNP))
# (S Telecommunications/NNS)
# (S (GPE Corporation/NN))
# (S (GPE China/NNP))
# (S (GPE Unicom/NN))
# (S KDDI/NNP)
# (S (GPE Nepal/NN))
# (S (GPE Telecom/NN))
# (S (ORGANIZATION NTT/NN))
# (S (GPE DoCoMo/NN))
# (S (ORGANIZATION SoftBank/NN))
# (S (GPE Group/NNP))
# (S (GPE Sprint/NN))
# (S (GPE Corporation/NN))
# (S (GPE T/NNP) -/: Mobile/NN)
# (S (GPE Telecom/NN))
# (S (GPE Italia/NNS))
# (S (GPE Telefónica/NN))
# (S (GPE Telus/NN))
# (S (GPE Vodafone/NN))
# (S (GPE Software/NN))
# (S companies/NNS)
# (S (GPE Access/NN))
# (S (GPE Ascender/NN))
# (S (GPE Corporation/NN))
# (S (ORGANIZATION eBay/NN))
# (S (GPE Google/NN))
# (S (GPE Myriad/NN))
# (S (GPE Group/NNP))
# (S (GPE Nuance/NN))
# (S Communications/NNS)
# (S (ORGANIZATION NXP/NN))
# (S (GPE Software/NN))
# (S (GPE Omron/NNP))
# (S (ORGANIZATION PacketVideo/NN))
# (S (ORGANIZATION SVOX/NN))
# (S (ORGANIZATION VisualOn/NN))
# (S (GPE Semiconductor/NN))
# (S companies/NNS)
# (S (ORGANIZATION AKM/NN))
# (S (GPE Semiconductor/NN))
# (S ,/,)
# (S (GPE Inc/NNP))
# (S ./.)
# (S (GPE Arm/NN))
# (S Holdings/NNS)
# (S (GPE Audience/NN))
# (S (GPE Broadcom/NNP))
# (S (ORGANIZATION CSR/NN))
# (S plc/NN)
# (S (/()
# (S joined/VBD)
# (S as/IN)
# (S (ORGANIZATION SiRF/NN))
# (S )/))
# (S (GPE Cypress/NN))
# (S (GPE Semiconductor/NN))
# (S (GPE Freescale/NN))
# (S (GPE Semiconductor/NN))
# (S (GPE Gemalto/NN))
# (S (GPE Intel/NNP))
# (S (PERSON Marvell/NNP))
# (S (GPE Technology/NN))
# (S (GPE Group/NNP))
# (S (ORGANIZATION MediaTek/NN))
# (S (ORGANIZATION MIPS/NN))
# (S Technologies/NNS)
# (S (GPE Nvidia/NNP))
# (S (GPE Qualcomm/NN))
# (S (GPE Qualcomm/NN))
# (S (GPE Atheros/NNS))
# (S (GPE Renesas/NN))
# (S Electronics/NNS)
# (S (GPE ST/NNP) -/: (PERSON Ericsson/NN))
# (S (/()
# (S joined/VBD)
# (S as/IN)
# (S (GPE Ericsson/NN))
# (S (GPE Mobile/NN))
# (S Platforms/NNS)
# (S )/))
# (S Synaptics/NNS)
# (S (GPE Texas/NNP))
# (S Instruments/NNS)
# (S (GPE Handset/NN))
# (S makers/NNS)
# (S (GPE Acer/NN))
# (S (GPE Inc/NNP) ./.)
# (S (GPE Alcatel/NN))
# (S (GPE Mobile/NN))
# (S Phones/NNS)
# (S (GPE Asus/NN))
# (S Chaudhary/JJ)
# (S (GPE Group/NNP))
# (S (/()
# (S with/IN)
# (S association/NN)
# (S of/IN)
# (S LG/NN)
# (S )/))
# (S (ORGANIZATION CCI/NN))
# (S (GPE Dell/NNP))
# (S (GPE Foxconn/NN))
# (S (GPE Garmin/NN))
# (S (ORGANIZATION HTC/NN))
# (S (GPE Huawei/NN))
# (S (GPE Kyocera/NN))
# (S (GPE Lenovo/NN))
# (S (GPE Mobile/NN))
# (S LG/NN)
# (S Electronics/NNS)
# (S (GPE Motorola/NNP))
# (S (GPE Mobility/NN))
# (S NEC/NNP)
# (S (GPE Corporation/NN))
# (S (GPE Samsung/NN))
# (S Electronics/NNS)
# (S (GPE Sharp/NN))
# (S (GPE Corporation/NN))
# (S (GPE Sony/NNP))
# (S (GPE Mobile/NN))
# (S (GPE Toshiba/NN))
# (S (ORGANIZATION ZTE/NN))
# (S Commercialization/NN)
# (S companies/NNS)
# (S (GPE Accenture/NN))
# (S (GPE Borqs/NN))
# (S (GPE Sasken/NN))
# (S Communication/NN)
# (S Technologies/NNS)
# (S (GPE Teleca/NN))
# (S The/DT)
# (S Astonishing/VBG)
# (S (GPE Tribe/NN))
# (S Wind/IN)
# (S (GPE River/NN))
# (S Systems/NNS)
# (S (GPE Wipro/NNP))
# (S Technologies/NNS)
# (S See/VB)
# (S also/RB)
# (S (GPE Android/NN))
# (S (GPE Dalvik/NN))
# (S virtual/JJ)
# (S machine/NN)
# (S (GPE Google/NN))
# (S (GPE Nexus/NN))
# (S (GPE T/NNP) -/: Mobile/NN)
# (S (GPE G1/NN))
# (S (ORGANIZATION vteGoogle/NN))
# (S (GPE Lunar/NN))
# (S X/NN)
# (S PrizeOrganizers/NNS)
# (S (GPE Google/NN))
# (S (GPE Sundar/NN))
# (S (GPE Pichai/NN))
# (S (PERSON Larry/NNP))
# (S Page/NN)
# (S (GPE Sergey/NN))
# (S (GPE Brin/NN))
# (S X/NN)
# (S Prize/VB)
# (S Foundation/NN)
# (S (PERSON Peter/NNP))
# (S (GPE Diamandis/NN))
# (S (GPE Finalist/NN))
# (S teams/NNS)
# (S (GPE Hakuto/NN))
# (S (GPE Moon/NNP))
# (S (GPE Express/NN))
# (S (GPE SpaceIL/NN))
# (S (GPE Synergy/NN))
# (S (GPE Moon/NNP))
# (S (ORGANIZATION TeamIndus/NN))
# (S (GPE Withdrawn/NN))
# (S teams/NNS)
# (S Advaeros/NNS)
# (S (ORGANIZATION AngelicvM/NN))
# (S (ORGANIZATION ARCA/NN))
# (S Astrobotic/JJ)
# (S (GPE Barcelona/NNP))
# (S (GPE Moon/NNP))
# (S (GPE Team/NN))
# (S (GPE C/NNP) -/: (PERSON Base/NN))
# (S Open/VB)
# (S (GPE Moon/NNP))
# (S (GPE Euroluna/NN))
# (S (GPE FREDNET/NN))
# (S (GPE Independence/NNP) -/: X/NN)
# (S (GPE JURBAN/NN))
# (S (ORGANIZATION LunaTrex/NN))
# (S (GPE Micro/NNP) -/: (GPE Space/NN))
# (S Mystical/JJ)
# (S (GPE Moon/NNP))
# (S Next/JJ)
# (S (GPE Giant/NN))
# (S Leap/VB)
# (S (GPE Odyssey/NN))
# (S (GPE Moon/NNP))
# (S (GPE Omega/NN))
# (S (GPE Envoy/NN))
# (S (GPE Part/SYM) -/: Time/NN)
# (S Scientists/NNS)
# (S (GPE Penn/NN))
# (S State/NN)
# (S (GPE Lunar/NN))
# (S (GPE Lion/NN))
# (S (GPE Team/NN))
# (S (GPE Team/NN))
# (S Puli/NNS)
# (S (GPE Quantum3/NN))
# (S (GPE Rocket/NN))
# (S (GPE City/NNP))
# (S (GPE Space/NN))
# (S Pioneers/NNS)
# (S (ORGANIZATION SCSG/NN))
# (S (GPE Selenokhod/NN))
# (S (ORGANIZATION SpaceMETA/NN))
# (S (ORGANIZATION STELLAR/NN))
# (S (GPE Team/NN))
# (S (GPE Italia/NNS))
# (S (GPE Team/NN))
# (S (GPE Phoenicia/NN))
# (S (GPE Team/NN))
# (S (GPE Plan/NN))
# (S B/NN)
# (S (GPE Team/NN))
# (S (GPE SELENE/NN))
# (S (GPE Spacecraft/NN))
# (S (GPE ALINA/NN))
# (S (/()
# (S (GPE Part/SYM) -/: Time/NN)
# (S Scientists/NNS)
# (S )/))
# (S (GPE Beresheet/NN))
# (S (/()
# (S (GPE SpaceIL/NN))
# (S )/))
# (S (ORGANIZATION HHK/NNP) -/: 1/CD)
# (S //NN)
# (S (ORGANIZATION ECA/NN))
# (S (/()
# (S (ORGANIZATION TeamIndus/NN))
# (S )/))
# (S (GPE MX/NNP) -/: 1E/CD)
# (S (/()
# (S (GPE Moon/NNP))
# (S (GPE Express/NN))
# (S )/))
# (S (GPE Peregrine/NN))
# (S (/()
# (S Astrobotic/JJ)
# (S )/))
# (S (ORGANIZATION SORATO/NN))
# (S (/()
# (S (GPE Hakuto/NN))
# (S )/))
# (S (GPE Tesla/NN))
# (S (/()
# (S (GPE Synergy/NN))
# (S (GPE Moon/NNP))
# (S )/))
# (S (GPE Unity/NN))
# (S (/()
# (S (ORGANIZATION AngelicvM/NN))
# (S )/))
# (S (ORGANIZATION vteMajor/NN))
# (S mobile/NN)
# (S device/NN)
# (S companiesCompanies/NNS)
# (S with/IN)
# (S an/DT)
# (S annual/JJ)
# (S revenue/NN)
# (S of/IN)
# (S over/IN)
# (S (GSP US/NN))
# (S $/$)
# (S 3/CD)
# (S billion/CD)
# (S (GPE Acer/NN))
# (S (GPE Amazon/NN))
# (S (GPE Apple/NNP))
# (S (ORGANIZATION iPad/NN))
# (S (ORGANIZATION iPhone/NN))
# (S (GPE Watch/NN))
# (S (GPE Asus/NN))
# (S (ORGANIZATION BBK/NN))
# (S Electronics/NNS)
# (S (GPE Oppo/NN))
# (S OnePlus/CC)
# (S (GPE Vivo/NN))
# (S (GPE Realme/NN))
# (S (ORGANIZATION BlackBerry/NNP))
# (S (GPE Limited/JJ))
# (S (GPE Foxconn/NN))
# (S (GPE Sharp/NN))
# (S (ORGANIZATION InFocus/NN))
# (S Essential/JJ)
# (S Products/NNS)
# (S (GPE Nokia/NNP))
# (S (GPE Google/NN))
# (S (GPE Pixel/NN))
# (S (GPE Android/NN))
# (S One/CD)
# (S (ORGANIZATION HTC/NN))
# (S HP/NN)
# (S (GPE Huawei/NN))
# (S (GPE Honor/NN))
# (S (GPE Lenovo/NN))
# (S (GPE Motorola/NNP))
# (S (GPE Mobility/NN))
# (S LG/NN)
# (S Electronics/NNS)
# (S (GPE Meizu/NN))
# (S (PERSON Microsoft/NNP))
# (S (GPE Mobile/NN))
# (S (PERSON Microsoft/NNP))
# (S (GPE Surface/NN))
# (S (GPE Phone/NN))
# (S (GPE Motorola/NNP))
# (S Solutions/NNS)
# (S (ORGANIZATION HMD/NN))
# (S (GPE Global/JJ))
# (S (GPE Nokia/NNP))
# (S (GPE Panasonic/NN))
# (S (GPE Samsung/NN))
# (S Electronics/NNS)
# (S (GPE Sony/NNP))
# (S (GPE Mobile/NN))
# (S (ORGANIZATION TCL/NN))
# (S (ORGANIZATION BlackBerry/NNP))
# (S (GPE Mobile/NN))
# (S (GPE Alcatel/NN))
# (S (GPE Mobile/NN))
# (S (GPE Palm/NN))
# (S Transsion/NN)
# (S (GPE Tecno/NN))
# (S (GPE Infinix/NN))
# (S (GPE Tinno/NN))
# (S (GPE Mobile/NN))
# (S (GPE Wiko/NN))
# (S (GPE True/NN))
# (S (GPE Xiaomi/NN))
# (S (GPE Redmi/NN))
# (S (GPE Pocophone/NN))
# (S (GPE Meitu/NN))
# (S (ORGANIZATION ZTE/NN))
# (S (GPE Nubia/NN))
# (S (GPE Walton/NNP))
# (S (GPE Mobile/NN))
# (S See/VB)
# (S also/RB)
# (S Largest/JJS)
# (S IT/NN)
# (S companies/NNS)
# (S (GPE Category/NN))
# (S :/:)
# (S (GPE Mobile/NN))
# (S technology/NN)
# (S companies/NNS)
# (S (GPE Category/NN))
# (S :/:)
# (S (GPE Mobile/NN))
# (S phone/NN)
# (S manufacturers/NNS)
# (S (ORGANIZATION vteMajor/NN))
# (S Internet/NN)
# (S companiesCompanies/NNS)
# (S with/IN)
# (S an/DT)
# (S annual/JJ)
# (S revenue/NN)
# (S of/IN)
# (S over/IN)
# (S (GSP US/NN))
# (S $/$)
# (S 2/CD)
# (S (ORGANIZATION billionLargest/NN))
# (S Internet/NN)
# (S companies/NNS)
# (S (GPE Alphabet/NN))
# (S (GPE Inc/NNP) ./.)
# (S (/()
# (S (GPE Google/NN))
# (S )/))
# (S (GPE Amazon/NN))
# (S (GPE Apple/NNP))
# (S (GPE Baidu/NN))
# (S (GPE Facebook/NN))
# (S (ORGANIZATION InterActiveCorp/NN))
# (S (PERSON Microsoft/NNP))
# (S (GPE Naver/NN))
# (S (ORGANIZATION NetEase/NN))
# (S (GPE Netflix/NN))
# (S (GPE Tencent/NN))
# (S Twitter/NN)
# (S (GPE Verizon/NN))
# (S (GPE Yandex/NN))
# (S (GPE Cloud/NN))
# (S computing/VBG)
# (S (GPE Akamai/NN))
# (S Technologies/NNS)
# (S (GPE Alibaba/NN))
# (S (GPE Cloud/NN))
# (S (GPE Amazon/NN))
# (S Web/NN)
# (S Services/NNS)
# (S (GPE Apple/NNP))
# (S (GPE iCloud/NN))
# (S (GPE Google/NN))
# (S IBM/NNP)
# (S (PERSON Microsoft/NNP))
# (S (GPE Azure/NN))
# (S (GPE Oracle/NN))
# (S (GPE Corporation/NN))
# (S (GPE Rackspace/NN))
# (S (GPE Salesforce/NNP) ./. com/NN)
# (S (ORGANIZATION ServiceNow/NN))
# (S E/LS -/: commerce/NN)
# (S only/RB)
# (S (GPE Alibaba/NN))
# (S (GPE Group/NNP))
# (S (GPE Amazon/NNP) ./. com/NN)
# (S (GPE Apple/NNP))
# (S (ORGANIZATION eBay/NN))
# (S (GPE Flipkart/NN))
# (S (GPE Groupon/NN))
# (S JD/NNP ./. com/NN)
# (S Shopify/VB)
# (S Rakuten/VB)
# (S See/VB)
# (S also/RB)
# (S Largest/JJS)
# (S IT/NN)
# (S companies/NNS)
# (S (GPE List/NN))
# (S of/IN)
# (S largest/JJS)
# (S Internet/NN)
# (S companies/NNS)
# (S (GPE Category/NN))
# (S :/:)
# (S Internet/NN)
# (S technology/NN)
# (S companies/NNS)
# (S (ORGANIZATION vteMajor/NN))
# (S software/NN)
# (S companiesCompanies/NNS)
# (S with/IN)
# (S annual/JJ)
# (S software/NN)
# (S revenue/NN)
# (S of/IN)
# (S over/IN)
# (S (GSP US/NN))
# (S $/$)
# (S 3/CD)
# ...
# (S articles/NNS)
# (S with/IN)
# (S (ORGANIZATION GND/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (ORGANIZATION ISNI/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (ORGANIZATION LCCN/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (ORGANIZATION NKC/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (ORGANIZATION NLA/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (GPE SELIBR/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (GPE SUDOC/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (GPE TePapa/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (ORGANIZATION VIAF/NN))
# (S (GPE identifiersWikipedia/NN))
# (S articles/NNS)
# (S with/IN)
# (S (ORGANIZATION WorldCat/NNP) -/: (ORGANIZATION VIAF/NN))
# (S identifiers/NNS)
# (S Navigation/NNP)
# (S menu/NN)
# (S Personal/JJ)
# (S tools/NNS)
# (S Not/RB)
# (S logged/VBN)
# (S in/IN)
# (S (ORGANIZATION TalkContributionsCreate/NN))
# (S (ORGANIZATION accountLog/NN))
# (S in/IN)
# (S Namespaces/NNS)
# (S (GSP ArticleTalk/NN))
# (S Variants/NNS)
# (S Views/NNS)
# (S (ORGANIZATION ReadView/NN))
# (S (GPE sourceView/NN))
# (S history/NN)
# (S More/RBR)
# (S (GPE Search/NN))
# (S Navigation/NNP)
# (S (GPE Main/NN))
# (S pageContentsFeatured/VBN)
# (S (ORGANIZATION contentCurrent/NN))
# (S eventsRandom/NN)
# (S (ORGANIZATION articleDonate/NN))
# (S to/TO)
# (S WikipediaWikipedia/NNP)
# (S store/NN)
# (S Interaction/NN)
# (S (ORGANIZATION HelpAbout/NN))
# (S WikipediaCommunity/NN)
# (S (GPE portalRecent/NN))
# (S changesContact/NN)
# (S page/NN)
# (S Tools/NNS)
# (S What/WP)
# (S links/NNS)
# (S hereRelated/VBN)
# (S changesUpload/NN)
# (S fileSpecial/JJ)
# (S (ORGANIZATION pagesPermanent/NN))
# (S (ORGANIZATION linkPage/NN))
# (S (ORGANIZATION informationWikidata/NN))
# (S (ORGANIZATION itemCite/NN))
# (S this/DT)
# (S page/NN)
# (S In/IN)
# (S other/JJ)
# (S projects/NNS)
# (S (GPE Wikimedia/NNP))
# (S
#   (ORGANIZATION CommonsMeta/NNP)
#   -/:
#   (ORGANIZATION WikiWikiquoteWikiversity/NN))
# (S (PERSON Print/NNP) //NNP export/NN)
# (S (GPE Create/NN))
# (S a/DT)
# (S bookDownload/NN)
# (S as/IN)
# (S PDFPrintable/JJ)
# (S version/NN)
# (S Languages/NNS)
# (S
#   (PERSON AfrikaansአማርኛÆngliscالعربيةঅসম/NNP)
#   ী/NNP
#   য/NNP
#   ়া/NNP
#   AsturianuAzərbaycancaتۆرکجهBaliBamanankanব/NNP
#   াং/NNP
#   ল/NNP
#   া/NNP
#   (ORGANIZATION BanjarBân/NNP)
#   -/:
#   lâm/NN
#   -/:
#   (ORGANIZATION gúБеларускаяБеларуская/NN))
# (S (/()
# (S тарашкевіца/NN)
# (S )/))
# (S
#   ‎/JJ
#   भ/NNP
#   ो/NNP
#   जप/NNP
#   ु/NNP
#   र/NNP
#   ी/NNP
#   БългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiड/NNP
#   ो/NNP
#   ट/NNP
#   े/NNP
#   ल/NNP
#   ी/NNP
#   EestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગ/NNP
#   ુ/NNP
#   જર/NNP
#   ા/NNP
#   ત/NNP
#   ી/NNP
#   客家語/NNP
#   //NNP
#   Hak/NNP
#   -/:
#   kâ/NN
#   -/:
#   (ORGANIZATION ngî한국어Հայերենह/NN)
#   ि/JJ
#   न/NNP
#   ्/NNP
#   द/NNP
#   ी/NNP
#   HornjoserbsceHrvatskiBahasa/NNP)
# (S (ORGANIZATION HulontaloIdoBahasa/NN))
# (S
#   (GPE Indonesiaᐃᓄᒃᑎᑐᑦ/NNP)
#   //NNP
#   inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ/NN
#   ್/NNP
#   ನಡქართულიҚазақшаKirundiKreyòl/NN)
# (S (ORGANIZATION ayisyenKurdîКыргызчаລາວلۊری/NN))
# (S
#   شومالیLatinaLatviešuLietuviųMagyarम/JJ
#   ै/NNP
#   थ/NNP
#   ि/NNP
#   ल/NNP
#   ी/NNP
#   МакедонскиMalagasyമലയ/NNP
#   ാ/NNP
#   ള/NNP
#   ം/NNP
#   मर/NNP
#   ा/NNP
#   ठ/NNP
#   ी/NNP
#   მარგალურიمصرىماز/NNP
#   ِ/NNP
#   رونیBahasa/NN)
# (S
#   (ORGANIZATION MelayuMìng/NNP)
#   -/:
#   dĕ/NN
#   ̤/NN
#   ng/SYM
#   -/:
#   ngṳ/JJ
#   ̄/NNP
#   (PERSON Монголမ/NNP)
#   ြ/NNP
#   န/NNP
#   ်/NNP
#   မ/NNP
#   ာ/NNP
#   ဘ/NNP
#   ာ/NNP
#   သ/NNP
#   ာ/NNP
#   NāhuatlNederlandsन/NNP
#   े/NNP
#   प/NNP
#   ा/NNP
#   ल/NNP
#   ी/NNP
#   日本語ߒߞߏNorsk/NN)
# (S (GPE bokmålNorsk/NN))
# (S
#   nynorskOccitanଓଡ/JJ
#   ଼ି/NNP
#   ଆOʻzbekcha/NNP
#   //NNP
#   ўзбекчаਪ/NNP
#   ੰ/NNP
#   ਜ/NNP
#   ਾ/NNP
#   ਬ/NNP
#   ੀ/NNP
#   پنجابیپښتوភ/NNP
#   ា/NNP
#   ស/NNP
#   ា/NNP
#   ខ/NNP
#   ្/NNP
#   ម/NNP
#   ែ/NNP
#   រPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna/NN)
# (S (ORGANIZATION SimiРусскийСаха/NN))
# (S тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuස/JJ ිං/CD හලSimple/NN)
# (S EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски/NN)
# (S //NN)
# (S (ORGANIZATION srpskiSrpskohrvatski/NN))
# (S //NN)
# (S
#   српскохрватскиSundaSuomiSvenskaTagalogதம/JJ
#   ி/NNP
#   ழ/NNP
#   ்/NNP
#   (PERSON Татарча/NNP)
#   //NNP
#   tatarçaత/NN
#   ె/NNP
#   ల/NNP
#   ు/NNP
#   గ/NNP
#   ు/NNP
#   TetunไทยТоҷикӣತ/NNP
#   ು/NNP
#   ಳ/NNP
#   ು/NNP
#   TürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە/NNP)
# (S //NN)
# (S UyghurcheVènetoTiếng/NN)
# (S
#   (GPE ViệtWalon文言West/NNP)
#   -/:
#   (ORGANIZATION VlamsWinaray吴语יי/NNP)
#   ִ/NNP
#   דישYorùbá粵語ZazakiZeêuwsŽemaitėška中文/NN)
# (S (GPE Edit/NN))
# (S links/NNS)
# (S This/DT)
# (S page/NN)
# (S was/VBD)
# (S last/JJ)
# (S edited/VBN)
# (S on/IN)
# (S 27/CD)
# (S February/NNP)
# (S 2020/CD)
# (S ,/,)
# (S at/IN)
# (S 00/CD :/: 04/CD)
# (S (/()
# (S (ORGANIZATION UTC/NN))
# (S )/))
# (S ./.)
# (S (GPE Text/NN))
# (S is/VBZ)
# (S available/JJ)
# (S under/IN)
# (S the/DT)
# (S Creative/JJ)
# (S Commons/NNS)
# (S (GPE Attribution/NNP) -/: (ORGANIZATION ShareAlike/NN))
# (S (GPE License/NN))
# (S ;/:)
# (S additional/JJ)
# (S terms/NNS)
# (S may/MD)
# (S apply/VB)
# (S ./.)
# (S By/IN)
# (S using/VBG)
# (S this/DT)
# (S site/NN)
# (S ,/,)
# (S you/PRP)
# (S agree/NN)
# (S to/TO)
# (S the/DT)
# (S Terms/NNS)
# (S of/IN)
# (S Use/NN)
# (S and/CC)
# (S (GPE Privacy/NN))
# (S (GPE Policy/NN))
# (S ./.)
# (S (GPE Wikipedia/NNP) ®/NN)
# (S is/VBZ)
# (S a/DT)
# (S registered/VBN)
# (S trademark/NN)
# (S of/IN)
# (S the/DT)
# (S (GPE Wikimedia/NNP))
# (S Foundation/NN)
# (S ,/,)
# (S (GPE Inc/NNP) ./.)
# (S ,/,)
# (S a/DT)
# (S non/JJ -/: profit/NN)
# (S organization/NN)
# (S ./.)
# (S (GPE Privacy/NN))
# (S policy/NN)
# (S About/IN)
# (S (GPE Wikipedia/NNP))
# (S Disclaimers/NNS)
# (S (GSP Contact/NN))
# (S (GPE Wikipedia/NNP))
# (S Developers/NNS)
# (S Statistics/NNS)
# (S (GPE Cookie/NN))
# (S statement/NN)
# (S (GPE Mobile/NN))
# (S view/NN)
# (S (/()
# (S
#   (ORGANIZATION RLQ/NNP)
#   =/NNP
#   window/NN
#   ./.
#   (ORGANIZATION RLQ/NNP)
#   ||/NN)
# (S [/NN)
# (S ]/NN)
# (S )/))
# (S ./. push/NN)
# (S (/()
# (S function/NN)
# (S (/()
# (S )/))
# (S {/()
# (S mw/NN ./. config/NN ./. set/VB)
# (S (/()
# (S {/()
# (S ``/``)
# (S (ORGANIZATION wgPageParseReport/NN))
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S limitreport/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S cputime/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S 4/CD ./. 300/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S walltime/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S 4/CD ./. 899/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S ppvisitednodes/NNS)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 17937/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 1000000/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S postexpandincludesize/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 823164/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 2097152/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S templateargumentsize/VB)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 51017/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 2097152/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S expansiondepth/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 27/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 40/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S expensivefunctioncount/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 39/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 500/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S unstrip/JJ -/: depth/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 1/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 20/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S unstrip/JJ -/: size/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 987275/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 5000000/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S entityaccesscount/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 6/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 400/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S timingprofile/NN)
# (S ''/'')
# (S :/:)
# (S [/NN)
# (S ``/``)
# (S 100/CD ./. 00/CD)
# (S %/NN)
# (S 4161/CD ./. 894/CD)
# (S 1/CD)
# (S -/: total/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 61/CD ./. 12/CD)
# (S %/NN)
# (S 2543/CD ./. 620/CD)
# (S 2/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S (GPE Reflist/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 34/LS ./. 09/CD)
# (S %/NN)
# (S 1418/CD ./. 602/CD)
# (S 209/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S (ORGANIZATION Cite_web/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 14/CD ./. 57/CD)
# (S %/NN)
# (S 606/CD ./. 189/CD)
# (S 1/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S (GPE Infobox_company/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 14/CD ./. 04/CD)
# (S %/NN)
# (S 584/CD ./. 332/CD)
# (S 1/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S (GPE Infobox/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 11/CD ./. 88/CD)
# (S %/NN)
# (S 494/CD ./. 280/CD)
# (S 68/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S Cite_news/NNS)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 10/CD ./. 17/CD)
# (S %/NN)
# (S 423/CD ./. 325/CD)
# (S 7/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S Wikidata/NNS)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 5/CD ./. 61/CD)
# (S %/NN)
# (S 233/CD ./. 280/CD)
# (S 1/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S Br_separated_entries/NNS)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 3/LS ./. 24/CD)
# (S %/NN)
# (S 135/CD ./. 041/CD)
# (S 10/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S Cite_journal/JJ)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 3/LS ./. 00/CD)
# (S %/NN)
# (S 124/CD ./. 827/CD)
# (S 17/CD)
# (S (GPE Template/NN))
# (S :/:)
# (S (GPE Navbox/NN))
# (S ''/'')
# (S ]/NN)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S scribunto/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S limitreport/NN -/: timeusage/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S 2/CD ./. 561/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S 10/CD ./. 000/CD)
# (S ''/'')
# (S }/))
# (S ,/,)
# (S ''/'')
# (S limitreport/NN -/: memusage/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S value/NN)
# (S ''/'')
# (S :/: 18175116/CD)
# (S ,/,)
# (S ''/'')
# (S limit/NN)
# (S ''/'')
# (S :/: 52428800/CD)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S limitreport/NN -/: logs/NNS)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S table/NN)
# (S #/#)
# (S 1/CD)
# (S {/()
# (S \/NNS n/NNS)
# (S }/))
# (S \/NNS ntable/JJ)
# (S #/#)
# (S 1/CD)
# (S {/()
# (S \/NNS n/NNS)
# (S }/))
# (S \/NNS ntable/JJ)
# (S #/#)
# (S 1/CD)
# (S {/()
# (S \/NNS n/NNS)
# (S }/))
# (S \/NNS ntable/JJ)
# (S #/#)
# (S 1/CD)
# (S {/()
# (S \/NNS n/NNS)
# (S }/))
# (S \/NNS n/NNS)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S limitreport/NN -/: profile/NN)
# (S ''/'')
# (S :/:)
# (S [/NN)
# (S [/NN)
# (S ``/``)
# (S Scribunto_LuaSandboxCallback/NN)
# (S :/:)
# (S :/: match/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 420/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 15/CD ./. 8/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S ?/.)
# (S ``/``)
# (S ,/,)
# (S ''/'')
# (S 240/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 9/CD ./. 0/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S recursiveClone/NN)
# (S
#   \/JJ
#   u003CmwInit/NN
#   ./.
#   lua/NN
#   :/:
#   41/CD
#   \/NNS
#   (ORGANIZATION u003E/JJ))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 220/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 8/CD ./. 3/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S (ORGANIZATION dataWrapper/NN))
# (S
#   \/JJ
#   (ORGANIZATION u003Cmw/NN)
#   ./.
#   lua/NN
#   :/:
#   661/CD
#   \/NNS
#   (ORGANIZATION u003E/JJ))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 200/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 7/CD ./. 5/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S Scribunto_LuaSandboxCallback/NN)
# (S :/:)
# (S :/: getEntity/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 160/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 6/CD ./. 0/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S Scribunto_LuaSandboxCallback/NN)
# (S :/:)
# (S :/: find/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 140/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 5/CD ./. 3/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S
#   \/JJ
#   (ORGANIZATION u003Cmw/NN)
#   ./.
#   lua/NN
#   :/:
#   683/CD
#   \/NNS
#   (ORGANIZATION u003E/JJ))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 100/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 3/LS ./. 8/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S Scribunto_LuaSandboxCallback/NN)
# (S :/:)
# (S :/: callParserFunction/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 80/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 3/LS ./. 0/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S Scribunto_LuaSandboxCallback/NN)
# (S :/:)
# (S :/: getExpandedArgument/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 80/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 3/LS ./. 0/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S Scribunto_LuaSandboxCallback/NN)
# (S :/:)
# (S :/: plain/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 80/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 3/LS ./. 0/CD)
# (S ''/'')
# (S ]/NN)
# (S ,/,)
# (S [/NN)
# (S ``/``)
# (S [/NN)
# (S others/NNS)
# (S ]/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 940/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S 35/CD ./. 3/CD)
# (S ''/'')
# (S ]/NN)
# (S ]/NN)
# (S }/))
# (S ,/,)
# (S ''/'')
# (S cachereport/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S origin/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S mw1241/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S timestamp/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S 20200305232510/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S ttl/NN)
# (S ''/'')
# (S :/: 2592000/CD)
# (S ,/,)
# (S ''/'')
# (S transientcontent/NN)
# (S ''/'')
# (S :/:)
# (S false/JJ)
# (S }/))
# (S }/))
# (S }/))
# (S )/))
# (S ;/:)
# (S }/))
# (S )/))
# (S ;/:)
# (S {/()
# (S ``/``)
# (S @/NN)
# (S context/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S https/NN)
# (S :/:)
# (S \/\//JJ schema/NN ./. org/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S @/NN)
# (S type/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S (GPE Article/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S name/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S (GPE Google/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S url/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S https/NN)
# (S :/:)
# (S
#   \/\//JJ
#   en/NN
#   ./.
#   wikipedia/NN
#   ./.
#   org/JJ
#   \//JJ
#   wiki/NN
#   \//NNP
#   Google/NNP)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S (ORGANIZATION sameAs/NN))
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S http/NN)
# (S :/:)
# (S
#   \/\//JJ
#   www/NN
#   ./.
#   wikidata/NN
#   ./.
#   org/JJ
#   \//JJ
#   entity/NN
#   \//NNP
#   Q95/NNP)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S (ORGANIZATION mainEntity/NN))
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S http/NN)
# (S :/:)
# (S
#   \/\//JJ
#   www/NN
#   ./.
#   wikidata/NN
#   ./.
#   org/JJ
#   \//JJ
#   entity/NN
#   \//NNP
#   Q95/NNP)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S author/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S @/NN)
# (S type/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S (GPE Organization/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S name/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S Contributors/NNS)
# (S to/TO)
# (S (GPE Wikimedia/NNP))
# (S projects/NNS)
# (S ''/'')
# (S }/))
# (S ,/,)
# (S ''/'')
# (S publisher/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S @/NN)
# (S type/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S (GPE Organization/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S name/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S (GPE Wikimedia/NNP))
# (S Foundation/NN)
# (S ,/,)
# (S (GPE Inc/NNP) ./.)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S logo/NN)
# (S ''/'')
# (S :/:)
# (S {/()
# (S ``/``)
# (S @/NN)
# (S type/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S (ORGANIZATION ImageObject/NN))
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S url/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S https/NN)
# (S :/:)
# (S
#   \/\//JJ
#   www/NN
#   ./.
#   wikimedia/NN
#   ./.
#   org/JJ
#   \//NNP
#   static/JJ
#   \//NNP
#   images/NNS
#   \//VBP
#   wmf/SYM
#   -/:
#   hor/NN
#   -/:
#   googpub/NN
#   ./.
#   png/NN)
# (S ''/'')
# (S }/))
# (S }/))
# (S ,/,)
# (S ''/'')
# (S datePublished/VBN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S 2004/CD -/: 10/CD -/: 22T20/CD :/: 08/CD :/: 26Z/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S dateModified/VBN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S 2020/CD -/: 02/CD -/: 27T00/CD :/: 04/CD :/: 44Z/CD)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S image/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S https/NN)
# (S :/:)
# (S
#   \/\//JJ
#   upload/NN
#   ./.
#   wikimedia/NN
#   ./.
#   org/JJ
#   \//JJ
#   wikipedia/NN
#   \//NNP
#   commons/NNS
#   \//VBP
#   3/CD
#   \//$
#   32/CD
#   \//NNP
#   Googleplex_HQ_/NNP)
# (S %/NN)
# (S 28cropped/CD)
# (S %/NN)
# (S 29/CD ./. jpg/NN)
# (S ''/'')
# (S ,/,)
# (S ''/'')
# (S headline/NN)
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S (GPE American/JJ))
# (S multinational/JJ)
# (S Internet/NN)
# (S and/CC)
# (S technology/NN)
# (S corporation/NN)
# (S ''/'')
# (S }/))
# (S (/()
# (S
#   (ORGANIZATION RLQ/NNP)
#   =/NNP
#   window/NN
#   ./.
#   (ORGANIZATION RLQ/NNP)
#   ||/NN)
# (S [/NN)
# (S ]/NN)
# (S )/))
# (S ./. push/NN)
# (S (/()
# (S function/NN)
# (S (/()
# (S )/))
# (S {/()
# (S mw/NN ./. config/NN ./. set/VB)
# (S (/()
# (S {/()
# (S ``/``)
# (S wgBackendResponseTime/NN)
# (S ''/'')
# (S :/: 132/CD)
# (S ,/,)
# (S ''/'')
# (S (ORGANIZATION wgHostname/NN))
# (S ''/'')
# (S :/:)
# (S ''/'')
# (S mw1401/NN)
# (S ''/'')
# (S }/))
# (S )/))
# (S ;/:)
# (S }/))
# (S )/))
# (S ;/:)

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier

# %%
twenty_train = fetch_20newsgroups(subset='train', shuffle=True)

tfidf_Vect = TfidfVectorizer()
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)

clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train_tfidf, twenty_train.target)

twenty_test = fetch_20newsgroups(subset='test', shuffle=True)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

predicted = clf.predict(X_test_tfidf)

score = metrics.accuracy_score(twenty_test.target, predicted)
print("KNeighborsClassifier Score",score)
# Out:
# KNeighborsClassifier Score 0.6578597981943707

# %%
from sklearn.naive_bayes import MultinomialNB

twenty_train = fetch_20newsgroups(subset='train', shuffle=True)

tfidf_Vect = TfidfVectorizer(ngram_range=(1,2))
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)

clf = MultinomialNB()
clf.fit(X_train_tfidf, twenty_train.target)

twenty_test = fetch_20newsgroups(subset='test', shuffle=True)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

predicted = clf.predict(X_test_tfidf)

score = metrics.accuracy_score(twenty_test.target, predicted)
print(score)
# Out:
# 0.765400955921402

# %%
twenty_train = fetch_20newsgroups(subset='train', shuffle=True)

tfidf_Vect = TfidfVectorizer(stop_words='english')
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)

clf = MultinomialNB()
clf.fit(X_train_tfidf, twenty_train.target)

twenty_test = fetch_20newsgroups(subset='test', shuffle=True)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

predicted = clf.predict(X_test_tfidf)

score = metrics.accuracy_score(twenty_test.target, predicted)
print(score)
# Out:
# 0.8169144981412639
